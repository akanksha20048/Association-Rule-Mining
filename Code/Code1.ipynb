# %%
#Import libraries
import pandas as pd
import numpy as np
import re
from google.colab import drive

# %%
drive.mount('/content/drive')
train_data = "drive/My Drive/dmg_assignment3/training.csv"

test_data = "drive/My Drive/dmg_assignment3/test_X.csv"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
train_df=pd.read_csv(train_data)

# %%
train_df
# Out:
#           id         Elevation  ... Horizontal_Distance_To_Fire_Points Label
# 0          0  elevation_medium  ...                               high     5
# 1          1  elevation_medium  ...                               high     5
# 2          2    elevation_high  ...                               high     2
# 3          3    elevation_high  ...                               high     2
# 4          4  elevation_medium  ...                               high     5
# ...      ...               ...  ...                                ...   ...
# 10995  10995  elevation_medium  ...                                low     3
# 10996  10996  elevation_medium  ...                                low     6
# 10997  10997  elevation_medium  ...                                low     3
# 10998  10998  elevation_medium  ...                                mid     3
# 10999  10999  elevation_medium  ...                                low     6
#
# [11000 rows x 12 columns]

# %%
columns=train_df.columns
columns

# for i in range(len(columns)):
#   if i!=0:
#     train_df.columns[i].unique()

print(train_df.Elevation.unique())
print(train_df.Aspect.unique())
print(train_df.Slope.unique())
print(train_df.Wilderness.unique())
print(train_df.Soil_Type.unique())

print(train_df.Hillshade_9am.unique())
print(train_df.Hillshade_noon.unique())

print(train_df.Horizontal_Distance_To_Hydrology.unique())
print(train_df.Vertical_Distance_To_Hydrology.unique())

print(train_df.Horizontal_Distance_To_Fire_Points.unique())
print(train_df.Label.unique())


train_df[:10]
# Out:
# ['elevation_medium' 'elevation_high' 'elevation_ultra' 'elevation_low']
# ['aspect_low' 'aspect_high' 'aspect_medium' 'aspect_ultra']
# ['slope_low' 'slope_high' 'slope_medium' 'slope_ultra']
# ['rawah' 'comanche' 'cache' 'neota']
# ['como_a' 'legault_a' 'como_b' 'rogert_a' 'cryaquolis_a' 'typic_b'
#  'leighcan_c' 'leighcan_b' 'moran_b' 'typic_a' 'supervisor_a' 'leighcan_a'
#  'moran_a' 'troutville_a' 'leighcan_i' 'leighcan_h' 'leighcan_g'
#  'catamount_b' 'bullwark_b' 'bullwark_a' 'vanet_b' 'leighcan_f' 'ratake_a'
#  'cathedral_a' 'catamount_a' 'vanet_a' 'gateview_a' 'haploborolis_a'
#  'cryorthents_a' 'vanet_c' 'pachic_a' 'rock_a' 'cryumbrepts_a' 'bross_a'
#  'typic_c' 'granile_a' 'leighcan_e' 'leighcan_d']
# ['hillshade_9am_min' 'hillshade_9am_max']
# ['hillnoon_max' 'hillnoon_min']
# [4 3 1 0 2 5 6]
# [0 3 4 1 2 5]
# ['high' 'mid' 'low']
# [5 2 1 7 3 6 4]
#    id         Elevation  ... Horizontal_Distance_To_Fire_Points Label
# 0   0  elevation_medium  ...                               high     5
# 1   1  elevation_medium  ...                               high     5
# 2   2    elevation_high  ...                               high     2
# 3   3    elevation_high  ...                               high     2
# 4   4  elevation_medium  ...                               high     5
# 5   5  elevation_medium  ...                               high     2
# 6   6  elevation_medium  ...                               high     5
# 7   7  elevation_medium  ...                               high     5
# 8   8  elevation_medium  ...                               high     5
# 9   9  elevation_medium  ...                               high     5
#
# [10 rows x 12 columns]

# %%
pathFile="drive/My Drive/dmg_assignment3/r1.txt"
file=open(pathFile)
content=file.read()
#content[1115:]

rules=[]
rule=""
for ch in content:
  if(ch !='\n'):
    rule+=ch
  else:
    rules.append(rule)
    rule=""

rules
# Out:
# ['=== Run information ===',
#  '',
#  'Scheme:       weka.associations.Apriori -N 700 -T 0 -C 0.6 -D 0.05 -U 1.0 -M 0.01 -S -1.0 -A -c -1',
#  'Relation:     training1-weka.filters.unsupervised.attribute.Remove-R1-weka.filters.unsupervised.attribute.Remove-R4,8-9',
#  'Instances:    11000',
#  'Attributes:   8',
#  '              Elevation',
#  '              Aspect',
#  '              Slope',
#  '              Soil_Type',
#  '              Hillshade_9am',
#  '              Hillshade_noon',
#  '              Horizontal_Distance_To_Fire_Points',
#  '              Label',
#  '=== Associator model (full training set) ===',
#  '',
#  '',
#  'Apriori',
#  '=======',
#  '',
#  'Minimum support: 0.01 (110 instances)',
#  'Minimum metric <confidence>: 0.6',
#  'Number of cycles performed: 20',
#  '',
#  'Generated sets of large itemsets:',
#  '',
#  'Size of set of large itemsets L(1): 142',
#  '',
#  'Size of set of large itemsets L(2): 622',
#  '',
#  'Size of set of large itemsets L(3): 807',
#  '',
#  'Size of set of large itemsets L(4): 486',
#  '',
#  'Size of set of large itemsets L(5): 156',
#  '',
#  'Size of set of large itemsets L(6): 29',
#  '',
#  'Size of set of large itemsets L(7): 3',
#  '',
#  'Best rules found:',
#  '',
#  '  1. Elevation=elevation_low Aspect=aspect_medium Slope=slope_ultra Soil_Type=haploborolis_a Horizontal_Distance_To_Fire_Points=mid 128 ==> Label=FOUR 128    conf:(1)',
#  '  2. Elevation=elevation_low Aspect=aspect_medium Slope=slope_ultra Soil_Type=haploborolis_a Hillshade_9am=hillshade_9am_max Horizontal_Distance_To_Fire_Points=mid 128 ==> Label=FOUR 128    conf:(1)',
#  '  3. Elevation=elevation_low Aspect=aspect_medium Slope=slope_ultra Soil_Type=haploborolis_a Hillshade_noon=hillnoon_min Horizontal_Distance_To_Fire_Points=mid 128 ==> Label=FOUR 128    conf:(1)',
#  '  4. Elevation=elevation_low Aspect=aspect_medium Slope=slope_ultra Soil_Type=haploborolis_a Hillshade_9am=hillshade_9am_max Hillshade_noon=hillnoon_min Horizontal_Distance_To_Fire_Points=mid 128 ==> Label=FOUR 128    conf:(1)',
#  '  5. Elevation=elevation_low Aspect=aspect_medium Soil_Type=haploborolis_a Horizontal_Distance_To_Fire_Points=mid 169 ==> Label=FOUR 168    conf:(0.99)',
#  '  6. Elevation=elevation_low Slope=slope_ultra Soil_Type=haploborolis_a Horizontal_Distance_To_Fire_Points=mid 168 ==> Label=FOUR 167    conf:(0.99)',
#  '  7. Elevation=elevation_low Aspect=aspect_medium Soil_Type=haploborolis_a Hillshade_9am=hillshade_9am_max Horizontal_Distance_To_Fire_Points=mid 167 ==> Label=FOUR 166    conf:(0.99)',
#  '  8. Elevation=elevation_low Slope=slope_ultra Soil_Type=haploborolis_a Hillshade_9am=hillshade_9am_max Horizontal_Distance_To_Fire_Points=mid 166 ==> Label=FOUR 165    conf:(0.99)',
#  '  9. Elevation=elevation_low Aspect=aspect_medium Soil_Type=haploborolis_a Hillshade_noon=hillnoon_min Horizontal_Distance_To_Fire_Points=mid 165 ==> Label=FOUR 164    conf:(0.99)',
#  ' 10. Elevation=elevation_low Aspect=aspect_medium Soil_Type=haploborolis_a Hillshade_9am=hillshade_9am_max Hillshade_noon=hillnoon_min Horizontal_Distance_To_Fire_Points=mid 164 ==> Label=FOUR 163    conf:(0.99)',
#  ' 11. Elevation=elevation_low Slope=slope_ultra Soil_Type=haploborolis_a Hillshade_noon=hillnoon_min Horizontal_Distance_To_Fire_Points=mid 163 ==> Label=FOUR 162    conf:(0.99)',
#  ' 12. Elevation=elevation_low Slope=slope_ultra Soil_Type=haploborolis_a Hillshade_9am=hillshade_9am_max Hillshade_noon=hillnoon_min Horizontal_Distance_To_Fire_Points=mid 163 ==> Label=FOUR 162    conf:(0.99)',
#  ' 13. Elevation=elevation_low Soil_Type=haploborolis_a Hillshade_noon=hillnoon_min Horizontal_Distance_To_Fire_Points=mid 219 ==> Label=FOUR 216    conf:(0.99)',
#  ' 14. Elevation=elevation_low Soil_Type=haploborolis_a Hillshade_9am=hillshade_9am_max Hillshade_noon=hillnoon_min Horizontal_Distance_To_Fire_Points=mid 215 ==> Label=FOUR 212    conf:(0.99)',
#  ' 15. Elevation=elevation_low Soil_Type=haploborolis_a Hillshade_9am=hillshade_9am_max Horizontal_Distance_To_Fire_Points=mid 232 ==> Label=FOUR 228    conf:(0.98)',
#  ' 16. Elevation=elevation_low Soil_Type=haploborolis_a Horizontal_Distance_To_Fire_Points=mid 248 ==> Label=FOUR 243    conf:(0.98)',
#  ' 17. Aspect=aspect_medium Soil_Type=moran_a 172 ==> Label=SEVEN 167    conf:(0.97)',
#  ' 18. Elevation=elevation_ultra Aspect=aspect_medium Soil_Type=moran_a 172 ==> Label=SEVEN 167    conf:(0.97)',
#  ' 19. Aspect=aspect_medium Soil_Type=moran_a Hillshade_9am=hillshade_9am_max 167 ==> Label=SEVEN 162    conf:(0.97)',
#  ' 20. Elevation=elevation_ultra Aspect=aspect_medium Soil_Type=moran_a Hillshade_9am=hillshade_9am_max 167 ==> Label=SEVEN 162    conf:(0.97)',
#  ' 21. Aspect=aspect_medium Soil_Type=moran_a Hillshade_noon=hillnoon_min 166 ==> Label=SEVEN 161    conf:(0.97)',
#  ' 22. Elevation=elevation_ultra Aspect=aspect_medium Soil_Type=moran_a Hillshade_noon=hillnoon_min 166 ==> Label=SEVEN 161    conf:(0.97)',
#  ' 23. Aspect=aspect_medium Soil_Type=moran_a Hillshade_9am=hillshade_9am_max Hillshade_noon=hillnoon_min 163 ==> Label=SEVEN 158    conf:(0.97)',
#  ' 24. Elevation=elevation_ultra Aspect=aspect_medium Soil_Type=moran_a Hillshade_9am=hillshade_9am_max Hillshade_noon=hillnoon_min 163 ==> Label=SEVEN 158    conf:(0.97)',
#  ' 25. Elevation=elevation_medium Aspect=aspect_medium Soil_Type=como_b Hillshade_noon=hillnoon_min 123 ==> Label=FIVE 119    conf:(0.97)',
#  ' 26. Elevation=elevation_medium Aspect=aspect_medium Soil_Type=como_b Hillshade_9am=hillshade_9am_max 122 ==> Label=FIVE 118    conf:(0.97)',
#  ' 27. Elevation=elevation_medium Aspect=aspect_medium Soil_Type=como_b Hillshade_9am=hillshade_9am_max Hillshade_noon=hillnoon_min 122 ==> Label=FIVE 118    conf:(0.97)',
#  ' 28. Slope=slope_ultra Soil_Type=haploborolis_a Hillshade_noon=hillnoon_min Horizontal_Distance_To_Fire_Points=mid 171 ==> Label=FOUR 165    conf:(0.96)',
#  ' 29. Slope=slope_ultra Soil_Type=haploborolis_a Hillshade_9am=hillshade_9am_max Hillshade_noon=hillnoon_min Horizontal_Distance_To_Fire_Points=mid 171 ==> Label=FOUR 165    conf:(0.96)',
#  ' 30. Soil_Type=moran_a Hillshade_noon=hillnoon_min Horizontal_Distance_To_Fire_Points=low 114 ==> Label=SEVEN 110    conf:(0.96)',
#  ' 31. Elevation=elevation_ultra Soil_Type=moran_a Hillshade_noon=hillnoon_min Horizontal_Distance_To_Fire_Points=low 114 ==> Label=SEVEN 110    conf:(0.96)',
#  ' 32. Aspect=aspect_medium Slope=slope_ultra Soil_Type=haploborolis_a Horizontal_Distance_To_Fire_Points=mid 133 ==> Label=FOUR 128    conf:(0.96)',
#  ' 33. Aspect=aspect_medium Slope=slope_ultra Soil_Type=haploborolis_a Hillshade_9am=hillshade_9am_max Horizontal_Distance_To_Fire_Points=mid 133 ==> Label=FOUR 128    conf:(0.96)',
#  ' 34. Aspect=aspect_medium Slope=slope_ultra Soil_Type=haploborolis_a Hillshade_noon=hillnoon_min Horizontal_Distance_To_Fire_Points=mid 133 ==> Label=FOUR 128    conf:(0.96)',
#  ' 35. Aspect=aspect_medium Slope=slope_ultra Soil_Type=haploborolis_a Hillshade_9am=hillshade_9am_max Hillshade_noon=hillnoon_min Horizontal_Distance_To_Fire_Points=mid 133 ==> Label=FOUR 128    conf:(0.96)',
#  ' 36. Slope=slope_ultra Soil_Type=haploborolis_a Hillshade_9am=hillshade_9am_max Horizontal_Distance_To_Fire_Points=mid 175 ==> Label=FOUR 168    conf:(0.96)',
#  ' 37. Elevation=elevation_medium Aspect=aspect_medium Soil_Type=como_b 124 ==> Label=FIVE 119    conf:(0.96)',
#  ' 38. Soil_Type=moran_a Hillshade_9am=hillshade_9am_max Horizontal_Distance_To_Fire_Points=mid 121 ==> Label=SEVEN 116    conf:(0.96)',
#  ' 39. Elevation=elevation_ultra Soil_Type=moran_a Hillshade_9am=hillshade_9am_max Horizontal_Distance_To_Fire_Points=mid 121 ==> Label=SEVEN 116    conf:(0.96)',
#  ' 40. Soil_Type=moran_a Hillshade_9am=hillshade_9am_max 213 ==> Label=SEVEN 204    conf:(0.96)',
#  ' 41. Elevation=elevation_ultra Soil_Type=moran_a Hillshade_9am=hillshade_9am_max 213 ==> Label=SEVEN 204    conf:(0.96)',
#  ' 42. Soil_Type=moran_a Hillshade_9am=hillshade_9am_max Hillshade_noon=hillnoon_min 188 ==> Label=SEVEN 180    conf:(0.96)',
#  ' 43. Elevation=elevation_ultra Soil_Type=moran_a Hillshade_9am=hillshade_9am_max Hillshade_noon=hillnoon_min 188 ==> Label=SEVEN 180    conf:(0.96)',
#  ' 44. Elevation=elevation_medium Soil_Type=como_b Hillshade_9am=hillshade_9am_max Hillshade_noon=hillnoon_min 138 ==> Label=FIVE 132    conf:(0.96)',
#  ' 45. Soil_Type=haploborolis_a Hillshade_noon=hillnoon_min Horizontal_Distance_To_Fire_Points=mid 229 ==> Label=FOUR 219    conf:(0.96)',
#  ' 46. Soil_Type=haploborolis_a Hillshade_9am=hillshade_9am_max Hillshade_noon=hillnoon_min Horizontal_Distance_To_Fire_Points=mid 225 ==> Label=FOUR 215    conf:(0.96)',
#  ' 47. Aspect=aspect_medium Soil_Type=haploborolis_a Horizontal_Distance_To_Fire_Points=mid 176 ==> Label=FOUR 168    conf:(0.95)',
#  ' 48. Aspect=aspect_medium Soil_Type=haploborolis_a Hillshade_9am=hillshade_9am_max Horizontal_Distance_To_Fire_Points=mid 174 ==> Label=FOUR 166    conf:(0.95)',
#  ' 49. Aspect=aspect_medium Soil_Type=haploborolis_a Hillshade_noon=hillnoon_min Horizontal_Distance_To_Fire_Points=mid 172 ==> Label=FOUR 164    conf:(0.95)',
#  ' 50. Aspect=aspect_medium Soil_Type=haploborolis_a Hillshade_9am=hillshade_9am_max Hillshade_noon=hillnoon_min Horizontal_Distance_To_Fire_Points=mid 171 ==> Label=FOUR 163    conf:(0.95)',
#  ' 51. Elevation=elevation_low Slope=slope_ultra Hillshade_9am=hillshade_9am_max Horizontal_Distance_To_Fire_Points=mid 184 ==> Label=FOUR 175    conf:(0.95)',
#  ' 52. Elevation=elevation_low Slope=slope_low Soil_Type=gateview_a Hillshade_9am=hillshade_9am_min 122 ==> Label=FOUR 116    conf:(0.95)',
#  ' 53. Elevation=elevation_low Slope=slope_ultra Hillshade_9am=hillshade_9am_max Hillshade_noon=hillnoon_min Horizontal_Distance_To_Fire_Points=mid 180 ==> Label=FOUR 171    conf:(0.95)',
#  ' 54. Elevation=elevation_low Aspect=aspect_medium Slope=slope_ultra Soil_Type=haploborolis_a 273 ==> Label=FOUR 259    conf:(0.95)',
#  ' 55. Elevation=elevation_low Aspect=aspect_medium Slope=slope_ultra Soil_Type=haploborolis_a Hillshade_9am=hillshade_9am_max 273 ==> Label=FOUR 259    conf:(0.95)',
#  ' 56. Elevation=elevation_low Aspect=aspect_medium Slope=slope_ultra Soil_Type=haploborolis_a Hillshade_noon=hillnoon_min 273 ==> Label=FOUR 259    conf:(0.95)',
#  ' 57. Elevation=elevation_low Aspect=aspect_medium Slope=slope_ultra Soil_Type=haploborolis_a Hillshade_9am=hillshade_9am_max Hillshade_noon=hillnoon_min 273 ==> Label=FOUR 259    conf:(0.95)',
#  ' 58. Aspect=aspect_ultra Soil_Type=moran_b 116 ==> Label=SEVEN 110    conf:(0.95)',
#  ' 59. Elevation=elevation_ultra Aspect=aspect_ultra Soil_Type=moran_b 116 ==> Label=SEVEN 110    conf:(0.95)',
#  ' 60. Aspect=aspect_ultra Soil_Type=moran_b Hillshade_9am=hillshade_9am_min 116 ==> Label=SEVEN 110    conf:(0.95)',
#  ' 61. Elevation=elevation_ultra Aspect=aspect_ultra Soil_Type=moran_b Hillshade_9am=hillshade_9am_min 116 ==> Label=SEVEN 110    conf:(0.95)',
#  ' 62. Elevation=elevation_medium Soil_Type=como_b Hillshade_9am=hillshade_9am_max 152 ==> Label=FIVE 144    conf:(0.95)',
#  ' 63. Soil_Type=haploborolis_a Hillshade_9am=hillshade_9am_max Horizontal_Distance_To_Fire_Points=mid 244 ==> Label=FOUR 231    conf:(0.95)',
#  ' 64. Elevation=elevation_low Slope=slope_low Soil_Type=gateview_a 131 ==> Label=FOUR 124    conf:(0.95)',
#  ' 65. Elevation=elevation_low Aspect=aspect_medium Slope=slope_ultra Horizontal_Distance_To_Fire_Points=mid 143 ==> Label=FOUR 135    conf:(0.94)',
#  ' 66. Elevation=elevation_low Aspect=aspect_medium Slope=slope_ultra Hillshade_9am=hillshade_9am_max Horizontal_Distance_To_Fire_Points=mid 143 ==> Label=FOUR 135    conf:(0.94)',
#  ' 67. Elevation=elevation_low Aspect=aspect_medium Slope=slope_ultra Hillshade_noon=hillnoon_min Horizontal_Distance_To_Fire_Points=mid 143 ==> Label=FOUR 135    conf:(0.94)',
#  ' 68. Elevation=elevation_low Aspect=aspect_medium Slope=slope_ultra Hillshade_9am=hillshade_9am_max Hillshade_noon=hillnoon_min Horizontal_Distance_To_Fire_Points=mid 143 ==> Label=FOUR 135    conf:(0.94)',
#  ' 69. Aspect=aspect_medium Slope=slope_ultra Soil_Type=como_b Horizontal_Distance_To_Fire_Points=mid 142 ==> Label=FIVE 134    conf:(0.94)',
#  ' 70. Aspect=aspect_medium Slope=slope_ultra Soil_Type=como_b Hillshade_noon=hillnoon_min Horizontal_Distance_To_Fire_Points=mid 142 ==> Label=FIVE 134    conf:(0.94)',
#  ' 71. Slope=slope_ultra Soil_Type=como_b Hillshade_9am=hillshade_9am_max Hillshade_noon=hillnoon_min Horizontal_Distance_To_Fire_Points=mid 139 ==> Label=FIVE 131    conf:(0.94)',
#  ' 72. Elevation=elevation_low Soil_Type=gateview_a Hillshade_noon=hillnoon_max 134 ==> Label=FOUR 126    conf:(0.94)',
#  ' 73. Aspect=aspect_medium Slope=slope_ultra Soil_Type=como_b Hillshade_9am=hillshade_9am_max Horizontal_Distance_To_Fire_Points=mid 133 ==> Label=FIVE 125    conf:(0.94)',
#  ' 74. Aspect=aspect_medium Slope=slope_ultra Soil_Type=como_b Hillshade_9am=hillshade_9am_max Hillshade_noon=hillnoon_min Horizontal_Distance_To_Fire_Points=mid 133 ==> Label=FIVE 125    conf:(0.94)',
#  ' 75. Elevation=elevation_low Slope=slope_ultra Soil_Type=haploborolis_a Hillshade_9am=hillshade_9am_max Hillshade_noon=hillnoon_min 424 ==> Label=FOUR 398    conf:(0.94)',
#  ' 76. Elevation=elevation_low Slope=slope_ultra Soil_Type=haploborolis_a 451 ==> Label=FOUR 423    conf:(0.94)',
#  ' 77. Elevation=elevation_low Slope=slope_ultra Soil_Type=haploborolis_a Hillshade_9am=hillshade_9am_max 432 ==> Label=FOUR 405    conf:(0.94)',
#  ' 78. Aspect=aspect_medium Slope=slope_ultra Soil_Type=como_b 176 ==> Label=FIVE 165    conf:(0.94)',
#  ' 79. Aspect=aspect_medium Slope=slope_ultra Soil_Type=como_b Hillshade_noon=hillnoon_min 176 ==> Label=FIVE 165    conf:(0.94)',
#  ' 80. Elevation=elevation_low Slope=slope_ultra Soil_Type=haploborolis_a Hillshade_noon=hillnoon_min 428 ==> Label=FOUR 401    conf:(0.94)',
#  ' 81. Elevation=elevation_low Soil_Type=gateview_a Hillshade_9am=hillshade_9am_min Hillshade_noon=hillnoon_max 126 ==> Label=FOUR 118    conf:(0.94)',
#  ' 82. Slope=slope_ultra Soil_Type=como_b Hillshade_9am=hillshade_9am_max Horizontal_Distance_To_Fire_Points=mid 140 ==> Label=FIVE 131    conf:(0.94)',
#  ' 83. Aspect=aspect_medium Slope=slope_ultra Soil_Type=como_b Hillshade_9am=hillshade_9am_max 167 ==> Label=FIVE 156    conf:(0.93)',
#  ' 84. Aspect=aspect_medium Slope=slope_ultra Soil_Type=como_b Hillshade_9am=hillshade_9am_max Hillshade_noon=hillnoon_min 167 ==> Label=FIVE 156    conf:(0.93)',
#  ' 85. Soil_Type=moran_a Horizontal_Distance_To_Fire_Points=low 151 ==> Label=SEVEN 141    conf:(0.93)',
#  ' 86. Elevation=elevation_ultra Soil_Type=moran_a Horizontal_Distance_To_Fire_Points=low 151 ==> Label=SEVEN 141    conf:(0.93)',
#  ' 87. Elevation=elevation_low Aspect=aspect_medium Hillshade_9am=hillshade_9am_max Horizontal_Distance_To_Fire_Points=mid 261 ==> Label=FOUR 243    conf:(0.93)',
#  ' 88. Elevation=elevation_low Aspect=aspect_medium Hillshade_noon=hillnoon_min Horizontal_Distance_To_Fire_Points=mid 261 ==> Label=FOUR 243    conf:(0.93)',
#  ' 89. Elevation=elevation_low Aspect=aspect_medium Horizontal_Distance_To_Fire_Points=mid 275 ==> Label=FOUR 256    conf:(0.93)',
#  ' 90. Elevation=elevation_low Aspect=aspect_medium Hillshade_9am=hillshade_9am_max Hillshade_noon=hillnoon_min Horizontal_Distance_To_Fire_Points=mid 257 ==> Label=FOUR 239    conf:(0.93)',
#  ' 91. Elevation=elevation_medium Soil_Type=como_b Hillshade_noon=hillnoon_min 157 ==> Label=FIVE 146    conf:(0.93)',
#  ' 92. Soil_Type=moran_b Hillshade_9am=hillshade_9am_min Hillshade_noon=hillnoon_min 196 ==> Label=SEVEN 182    conf:(0.93)',
#  ' 93. Elevation=elevation_ultra Soil_Type=moran_b Hillshade_9am=hillshade_9am_min Hillshade_noon=hillnoon_min 196 ==> Label=SEVEN 182    conf:(0.93)',
#  ' 94. Elevation=elevation_ultra Slope=slope_high Soil_Type=moran_a Hillshade_noon=hillnoon_min 153 ==> Label=SEVEN 142    conf:(0.93)',
#  ' 95. Elevation=elevation_low Aspect=aspect_high Slope=slope_ultra Soil_Type=haploborolis_a 176 ==> Label=FOUR 163    conf:(0.93)',
#  ' 96. Elevation=elevation_low Hillshade_9am=hillshade_9am_max Horizontal_Distance_To_Fire_Points=mid 351 ==> Label=FOUR 325    conf:(0.93)',
#  ' 97. Elevation=elevation_low Hillshade_9am=hillshade_9am_max Hillshade_noon=hillnoon_min Horizontal_Distance_To_Fire_Points=mid 320 ==> Label=FOUR 296    conf:(0.93)',
#  ' 98. Aspect=aspect_high Slope=slope_ultra Soil_Type=haploborolis_a Hillshade_noon=hillnoon_min 156 ==> Label=FOUR 144    conf:(0.92)',
#  ' 99. Soil_Type=moran_b Hillshade_9am=hillshade_9am_min 258 ==> Label=SEVEN 238    conf:(0.92)',
#  '100. Elevation=elevation_ultra Soil_Type=moran_b Hillshade_9am=hillshade_9am_min 258 ==> Label=SEVEN 238    conf:(0.92)',
#  '101. Slope=slope_high Soil_Type=moran_a Hillshade_noon=hillnoon_min 154 ==> Label=SEVEN 142    conf:(0.92)',
#  '102. Aspect=aspect_high Slope=slope_ultra Soil_Type=haploborolis_a Hillshade_9am=hillshade_9am_max Hillshade_noon=hillnoon_min 154 ==> Label=FOUR 142    conf:(0.92)',
#  '103. Elevation=elevation_low Aspect=aspect_high Slope=slope_ultra Soil_Type=haploborolis_a Hillshade_noon=hillnoon_min 153 ==> Label=FOUR 141    conf:(0.92)',
#  '104. Elevation=elevation_low Aspect=aspect_high Slope=slope_ultra Soil_Type=haploborolis_a Hillshade_9am=hillshade_9am_max Hillshade_noon=hillnoon_min 151 ==> Label=FOUR 139    conf:(0.92)',
#  '105. Slope=slope_ultra Soil_Type=como_b Hillshade_9am=hillshade_9am_max Hillshade_noon=hillnoon_min 186 ==> Label=FIVE 171    conf:(0.92)',
#  '106. Elevation=elevation_low Aspect=aspect_high Slope=slope_ultra Soil_Type=haploborolis_a Hillshade_9am=hillshade_9am_max 159 ==> Label=FOUR 146    conf:(0.92)',
#  '107. Slope=slope_ultra Soil_Type=haploborolis_a Hillshade_9am=hillshade_9am_max Hillshade_noon=hillnoon_min 437 ==> Label=FOUR 401    conf:(0.92)',
#  '108. Elevation=elevation_low Aspect=aspect_medium Soil_Type=haploborolis_a 370 ==> Label=FOUR 339    conf:(0.92)',
#  '109. Aspect=aspect_medium Slope=slope_ultra Soil_Type=haploborolis_a 283 ==> Label=FOUR 259    conf:(0.92)',
#  '110. Aspect=aspect_medium Slope=slope_ultra Soil_Type=haploborolis_a Hillshade_9am=hillshade_9am_max 283 ==> Label=FOUR 259    conf:(0.92)',
#  '111. Aspect=aspect_medium Slope=slope_ultra Soil_Type=haploborolis_a Hillshade_noon=hillnoon_min 283 ==> Label=FOUR 259    conf:(0.92)',
#  '112. Aspect=aspect_medium Slope=slope_ultra Soil_Type=haploborolis_a Hillshade_9am=hillshade_9am_max Hillshade_noon=hillnoon_min 283 ==> Label=FOUR 259    conf:(0.92)',
#  '113. Elevation=elevation_low Aspect=aspect_medium Soil_Type=haploborolis_a Hillshade_9am=hillshade_9am_max 365 ==> Label=FOUR 334    conf:(0.92)',
#  '114. Elevation=elevation_low Aspect=aspect_medium Soil_Type=haploborolis_a Hillshade_noon=hillnoon_min 365 ==> Label=FOUR 334    conf:(0.92)',
#  '115. Slope=slope_low Soil_Type=leighcan_i Horizontal_Distance_To_Fire_Points=mid 141 ==> Label=SEVEN 129    conf:(0.91)',
#  '116. Elevation=elevation_ultra Slope=slope_low Soil_Type=leighcan_i Horizontal_Distance_To_Fire_Points=mid 141 ==> Label=SEVEN 129    conf:(0.91)',
#  '117. Elevation=elevation_low Soil_Type=haploborolis_a Hillshade_noon=hillnoon_min 584 ==> Label=FOUR 534    conf:(0.91)',
#  '118. Elevation=elevation_low Aspect=aspect_medium Soil_Type=haploborolis_a Hillshade_9am=hillshade_9am_max Hillshade_noon=hillnoon_min 361 ==> Label=FOUR 330    conf:(0.91)',
#  '119. Slope=slope_ultra Soil_Type=haploborolis_a Hillshade_noon=hillnoon_min 442 ==> Label=FOUR 404    conf:(0.91)',
#  '120. Soil_Type=leighcan_i Hillshade_noon=hillnoon_max Horizontal_Distance_To_Fire_Points=mid 127 ==> Label=SEVEN 116    conf:(0.91)',
#  '121. Elevation=elevation_ultra Soil_Type=leighcan_i Hillshade_noon=hillnoon_max Horizontal_Distance_To_Fire_Points=mid 127 ==> Label=SEVEN 116    conf:(0.91)',
#  '122. Slope=slope_ultra Soil_Type=haploborolis_a Hillshade_9am=hillshade_9am_max 447 ==> Label=FOUR 408    conf:(0.91)',
#  '123. Elevation=elevation_low Soil_Type=haploborolis_a Hillshade_9am=hillshade_9am_max Hillshade_noon=hillnoon_min 549 ==> Label=FOUR 501    conf:(0.91)',
#  '124. Elevation=elevation_low Aspect=aspect_high Slope=slope_ultra Soil_Type=haploborolis_a Horizontal_Distance_To_Fire_Points=low 136 ==> Label=FOUR 124    conf:(0.91)',
#  '125. Aspect=aspect_high Soil_Type=haploborolis_a Hillshade_noon=hillnoon_min 192 ==> Label=FOUR 175    conf:(0.91)',
#  '126. Soil_Type=leighcan_i Hillshade_9am=hillshade_9am_min Hillshade_noon=hillnoon_min Horizontal_Distance_To_Fire_Points=mid 124 ==> Label=SEVEN 113    conf:(0.91)',
#  '127. Elevation=elevation_ultra Soil_Type=leighcan_i Hillshade_9am=hillshade_9am_min Hillshade_noon=hillnoon_min Horizontal_Distance_To_Fire_Points=mid 124 ==> Label=SEVEN 113    conf:(0.91)',
#  '128. Aspect=aspect_high Soil_Type=haploborolis_a Hillshade_9am=hillshade_9am_max Hillshade_noon=hillnoon_min 190 ==> Label=FOUR 173    conf:(0.91)',
#  '129. Elevation=elevation_low Aspect=aspect_high Soil_Type=haploborolis_a Hillshade_noon=hillnoon_min 189 ==> Label=FOUR 172    conf:(0.91)',
#  '130. Elevation=elevation_low Soil_Type=haploborolis_a 664 ==> Label=FOUR 604    conf:(0.91)',
#  '131. Elevation=elevation_low Aspect=aspect_high Soil_Type=haploborolis_a Hillshade_9am=hillshade_9am_max Hillshade_noon=hillnoon_min 187 ==> Label=FOUR 170    conf:(0.91)',
#  '132. Slope=slope_low Soil_Type=leighcan_i Hillshade_9am=hillshade_9am_min Horizontal_Distance_To_Fire_Points=mid 121 ==> Label=SEVEN 110    conf:(0.91)',
#  '133. Elevation=elevation_ultra Slope=slope_low Soil_Type=leighcan_i Hillshade_9am=hillshade_9am_min Horizontal_Distance_To_Fire_Points=mid 121 ==> Label=SEVEN 110    conf:(0.91)',
#  '134. Elevation=elevation_low Soil_Type=gateview_a 285 ==> Label=FOUR 259    conf:(0.91)',
#  '135. Aspect=aspect_high Slope=slope_ultra Soil_Type=haploborolis_a Hillshade_9am=hillshade_9am_max 164 ==> Label=FOUR 149    conf:(0.91)',
#  '136. Elevation=elevation_low Soil_Type=haploborolis_a Hillshade_9am=hillshade_9am_max 583 ==> Label=FOUR 529    conf:(0.91)',
#  '137. Elevation=elevation_ultra Soil_Type=moran_a Hillshade_noon=hillnoon_min 406 ==> Label=SEVEN 368    conf:(0.91)',
#  '138. Soil_Type=leighcan_i Hillshade_9am=hillshade_9am_min Horizontal_Distance_To_Fire_Points=mid 235 ==> Label=SEVEN 213    conf:(0.91)',
#  '139. Elevation=elevation_ultra Soil_Type=leighcan_i Hillshade_9am=hillshade_9am_min Horizontal_Distance_To_Fire_Points=mid 235 ==> Label=SEVEN 213    conf:(0.91)',
#  '140. Aspect=aspect_high Soil_Type=leighcan_i Hillshade_noon=hillnoon_max 148 ==> Label=SEVEN 134    conf:(0.91)',
#  '141. Elevation=elevation_ultra Aspect=aspect_high Soil_Type=leighcan_i Hillshade_noon=hillnoon_max 148 ==> Label=SEVEN 134    conf:(0.91)',
#  '142. Slope=slope_ultra Soil_Type=como_b Hillshade_9am=hillshade_9am_max 189 ==> Label=FIVE 171    conf:(0.9)',
#  '143. Elevation=elevation_low Slope=slope_low Horizontal_Distance_To_Fire_Points=mid 126 ==> Label=FOUR 114    conf:(0.9)',
#  '144. Elevation=elevation_low Slope=slope_ultra Soil_Type=haploborolis_a Horizontal_Distance_To_Fire_Points=low 283 ==> Label=FOUR 256    conf:(0.9)',
#  '145. Elevation=elevation_low Slope=slope_ultra Soil_Type=haploborolis_a Hillshade_9am=hillshade_9am_max Hillshade_noon=hillnoon_min Horizontal_Distance_To_Fire_Points=low 261 ==> Label=FOUR 236    conf:(0.9)',
#  '146. Elevation=elevation_medium Soil_Type=como_b 177 ==> Label=FIVE 160    conf:(0.9)',
#  '147. Elevation=elevation_low Aspect=aspect_medium Slope=slope_ultra Soil_Type=haploborolis_a Horizontal_Distance_To_Fire_Points=low 145 ==> Label=FOUR 131    conf:(0.9)',
#  '148. Elevation=elevation_low Aspect=aspect_medium Slope=slope_ultra Soil_Type=haploborolis_a Hillshade_9am=hillshade_9am_max Horizontal_Distance_To_Fire_Points=low 145 ==> Label=FOUR 131    conf:(0.9)',
#  '149. Elevation=elevation_low Aspect=aspect_medium Slope=slope_ultra Soil_Type=haploborolis_a Hillshade_noon=hillnoon_min Horizontal_Distance_To_Fire_Points=low 145 ==> Label=FOUR 131    conf:(0.9)',
#  '150. Elevation=elevation_low Aspect=aspect_medium Slope=slope_ultra Soil_Type=haploborolis_a Hillshade_9am=hillshade_9am_max Hillshade_noon=hillnoon_min Horizontal_Distance_To_Fire_Points=low 145 ==> Label=FOUR 131    conf:(0.9)',
#  '151. Elevation=elevation_low Soil_Type=gateview_a Hillshade_9am=hillshade_9am_min 257 ==> Label=FOUR 232    conf:(0.9)',
#  '152. Elevation=elevation_low Slope=slope_ultra Soil_Type=haploborolis_a Hillshade_9am=hillshade_9am_max Horizontal_Distance_To_Fire_Points=low 266 ==> Label=FOUR 240    conf:(0.9)',
#  '153. Soil_Type=moran_a Hillshade_noon=hillnoon_min 408 ==> Label=SEVEN 368    conf:(0.9)',
#  '154. Elevation=elevation_low Slope=slope_ultra Soil_Type=haploborolis_a Hillshade_noon=hillnoon_min Horizontal_Distance_To_Fire_Points=low 265 ==> Label=FOUR 239    conf:(0.9)',
#  '155. Soil_Type=moran_b 331 ==> Label=SEVEN 298    conf:(0.9)',
#  '156. Elevation=elevation_ultra Soil_Type=moran_b 331 ==> Label=SEVEN 298    conf:(0.9)',
#  '157. Aspect=aspect_high Soil_Type=leighcan_i 149 ==> Label=SEVEN 134    conf:(0.9)',
#  '158. Elevation=elevation_ultra Aspect=aspect_high Soil_Type=leighcan_i 149 ==> Label=SEVEN 134    conf:(0.9)',
#  '159. Soil_Type=moran_b Hillshade_noon=hillnoon_min 258 ==> Label=SEVEN 232    conf:(0.9)',
#  '160. Elevation=elevation_ultra Soil_Type=moran_b Hillshade_noon=hillnoon_min 258 ==> Label=SEVEN 232    conf:(0.9)',
#  '161. Elevation=elevation_low Aspect=aspect_high Soil_Type=haploborolis_a 260 ==> Label=FOUR 233    conf:(0.9)',
#  '162. Elevation=elevation_ultra Slope=slope_high Soil_Type=moran_a 181 ==> Label=SEVEN 162    conf:(0.9)',
#  '163. Slope=slope_ultra Soil_Type=haploborolis_a Horizontal_Distance_To_Fire_Points=mid 190 ==> Label=FOUR 170    conf:(0.89)',
#  '164. Aspect=aspect_high Soil_Type=leighcan_i Hillshade_9am=hillshade_9am_min 123 ==> Label=SEVEN 110    conf:(0.89)',
#  '165. Elevation=elevation_ultra Aspect=aspect_high Soil_Type=leighcan_i Hillshade_9am=hillshade_9am_min 123 ==> Label=SEVEN 110    conf:(0.89)',
#  '166. Aspect=aspect_high Soil_Type=leighcan_i Hillshade_9am=hillshade_9am_min Hillshade_noon=hillnoon_max 123 ==> Label=SEVEN 110    conf:(0.89)',
#  '167. Elevation=elevation_ultra Aspect=aspect_high Soil_Type=leighcan_i Hillshade_9am=hillshade_9am_min Hillshade_noon=hillnoon_max 123 ==> Label=SEVEN 110    conf:(0.89)',
#  '168. Soil_Type=como_b Hillshade_9am=hillshade_9am_max Horizontal_Distance_To_Fire_Points=low 151 ==> Label=FIVE 135    conf:(0.89)',
#  '169. Elevation=elevation_low Aspect=aspect_high Soil_Type=haploborolis_a Hillshade_9am=hillshade_9am_max 217 ==> Label=FOUR 194    conf:(0.89)',
#  '170. Aspect=aspect_ultra Soil_Type=leighcan_i 158 ==> Label=SEVEN 141    conf:(0.89)',
#  '171. Elevation=elevation_ultra Aspect=aspect_ultra Soil_Type=leighcan_i 158 ==> Label=SEVEN 141    conf:(0.89)',
#  '172. Aspect=aspect_ultra Soil_Type=leighcan_i Hillshade_9am=hillshade_9am_min 158 ==> Label=SEVEN 141    conf:(0.89)',
#  '173. Elevation=elevation_ultra Aspect=aspect_ultra Soil_Type=leighcan_i Hillshade_9am=hillshade_9am_min 158 ==> Label=SEVEN 141    conf:(0.89)',
#  '174. Soil_Type=como_b Hillshade_9am=hillshade_9am_max Hillshade_noon=hillnoon_min Horizontal_Distance_To_Fire_Points=low 130 ==> Label=FIVE 116    conf:(0.89)',
#  '175. Slope=slope_medium Soil_Type=leighcan_i Hillshade_9am=hillshade_9am_min 148 ==> Label=SEVEN 132    conf:(0.89)',
#  '176. Elevation=elevation_ultra Slope=slope_medium Soil_Type=leighcan_i Hillshade_9am=hillshade_9am_min 148 ==> Label=SEVEN 132    conf:(0.89)',
#  '177. Aspect=aspect_high Soil_Type=haploborolis_a Hillshade_noon=hillnoon_min Horizontal_Distance_To_Fire_Points=low 138 ==> Label=FOUR 123    conf:(0.89)',
#  '178. Elevation=elevation_low Aspect=aspect_high Soil_Type=haploborolis_a Hillshade_noon=hillnoon_min Horizontal_Distance_To_Fire_Points=low 138 ==> Label=FOUR 123    conf:(0.89)',
#  '179. Soil_Type=leighcan_i Horizontal_Distance_To_Fire_Points=mid 294 ==> Label=SEVEN 262    conf:(0.89)',
#  '180. Elevation=elevation_ultra Soil_Type=leighcan_i Horizontal_Distance_To_Fire_Points=mid 294 ==> Label=SEVEN 262    conf:(0.89)',
#  '181. Soil_Type=haploborolis_a Hillshade_9am=hillshade_9am_max Hillshade_noon=hillnoon_min 566 ==> Label=FOUR 504    conf:(0.89)',
#  '182. Slope=slope_high Soil_Type=moran_a 182 ==> Label=SEVEN 162    conf:(0.89)',
#  '183. Aspect=aspect_high Soil_Type=haploborolis_a Hillshade_9am=hillshade_9am_max Hillshade_noon=hillnoon_min Horizontal_Distance_To_Fire_Points=low 136 ==> Label=FOUR 121    conf:(0.89)',
#  '184. Elevation=elevation_low Aspect=aspect_high Soil_Type=haploborolis_a Hillshade_9am=hillshade_9am_max Hillshade_noon=hillnoon_min Horizontal_Distance_To_Fire_Points=low 136 ==> Label=FOUR 121    conf:(0.89)',
#  '185. Soil_Type=haploborolis_a Hillshade_noon=hillnoon_min 604 ==> Label=FOUR 537    conf:(0.89)',
#  '186. Soil_Type=leighcan_i Hillshade_noon=hillnoon_max 259 ==> Label=SEVEN 230    conf:(0.89)',
#  '187. Elevation=elevation_ultra Soil_Type=leighcan_i Hillshade_noon=hillnoon_max 259 ==> Label=SEVEN 230    conf:(0.89)',
#  '188. Slope=slope_ultra Soil_Type=haploborolis_a Hillshade_9am=hillshade_9am_max Hillshade_noon=hillnoon_min Horizontal_Distance_To_Fire_Points=low 266 ==> Label=FOUR 236    conf:(0.89)',
#  '189. Slope=slope_ultra Soil_Type=como_b Hillshade_noon=hillnoon_min Horizontal_Distance_To_Fire_Points=mid 177 ==> Label=FIVE 157    conf:(0.89)',
#  '190. Elevation=elevation_ultra Aspect=aspect_low Soil_Type=moran_a 141 ==> Label=SEVEN 125    conf:(0.89)',
#  '191. Elevation=elevation_low Aspect=aspect_low Slope=slope_low 141 ==> Label=FOUR 125    conf:(0.89)',
#  '192. Elevation=elevation_ultra Aspect=aspect_low Soil_Type=moran_a Hillshade_noon=hillnoon_min 141 ==> Label=SEVEN 125    conf:(0.89)',
#  '193. Elevation=elevation_low Aspect=aspect_low Slope=slope_low Hillshade_9am=hillshade_9am_min 141 ==> Label=FOUR 125    conf:(0.89)',
#  '194. Elevation=elevation_ultra Aspect=aspect_low Soil_Type=moran_a Hillshade_9am=hillshade_9am_min 131 ==> Label=SEVEN 116    conf:(0.89)',
#  '195. Elevation=elevation_ultra Aspect=aspect_low Soil_Type=moran_a Hillshade_9am=hillshade_9am_min Hillshade_noon=hillnoon_min 131 ==> Label=SEVEN 116    conf:(0.89)',
#  '196. Soil_Type=moran_b Hillshade_9am=hillshade_9am_min Horizontal_Distance_To_Fire_Points=mid 146 ==> Label=SEVEN 129    conf:(0.88)',
#  '197. Elevation=elevation_ultra Soil_Type=moran_b Hillshade_9am=hillshade_9am_min Horizontal_Distance_To_Fire_Points=mid 146 ==> Label=SEVEN 129    conf:(0.88)',
#  '198. Aspect=aspect_medium Soil_Type=haploborolis_a 384 ==> Label=FOUR 339    conf:(0.88)',
#  '199. Slope=slope_ultra Soil_Type=haploborolis_a Hillshade_9am=hillshade_9am_max Horizontal_Distance_To_Fire_Points=low 272 ==> Label=FOUR 240    conf:(0.88)',
#  '200. Slope=slope_ultra Soil_Type=haploborolis_a Hillshade_noon=hillnoon_min Horizontal_Distance_To_Fire_Points=low 271 ==> Label=FOUR 239    conf:(0.88)',
#  '201. Elevation=elevation_high Soil_Type=catamount_a Hillshade_9am=hillshade_9am_max Hillshade_noon=hillnoon_min 135 ==> Label=FIVE 119    conf:(0.88)',
#  '202. Aspect=aspect_medium Soil_Type=haploborolis_a Hillshade_9am=hillshade_9am_max 379 ==> Label=FOUR 334    conf:(0.88)',
#  '203. Aspect=aspect_medium Soil_Type=haploborolis_a Hillshade_noon=hillnoon_min 379 ==> Label=FOUR 334    conf:(0.88)',
#  '204. Elevation=elevation_ultra Soil_Type=moran_a Hillshade_noon=hillnoon_min Horizontal_Distance_To_Fire_Points=mid 244 ==> Label=SEVEN 215    conf:(0.88)',
#  '205. Elevation=elevation_low Soil_Type=gateview_a Hillshade_noon=hillnoon_min 151 ==> Label=FOUR 133    conf:(0.88)',
#  '206. Aspect=aspect_low Soil_Type=moran_a 142 ==> Label=SEVEN 125    conf:(0.88)',
#  '207. Elevation=elevation_low Aspect=aspect_high Horizontal_Distance_To_Fire_Points=mid 142 ==> Label=FOUR 125    conf:(0.88)',
#  '208. Aspect=aspect_low Soil_Type=moran_a Hillshade_noon=hillnoon_min 142 ==> Label=SEVEN 125    conf:(0.88)',
#  '209. Aspect=aspect_medium Soil_Type=haploborolis_a Hillshade_9am=hillshade_9am_max Hillshade_noon=hillnoon_min 375 ==> Label=FOUR 330    conf:(0.88)',
#  '210. Elevation=elevation_low Soil_Type=gateview_a Horizontal_Distance_To_Fire_Points=low 208 ==> Label=FOUR 183    conf:(0.88)',
#  '211. Aspect=aspect_low Soil_Type=moran_a Hillshade_9am=hillshade_9am_min 132 ==> Label=SEVEN 116    conf:(0.88)',
#  '212. Aspect=aspect_low Soil_Type=moran_a Hillshade_9am=hillshade_9am_min Hillshade_noon=hillnoon_min 132 ==> Label=SEVEN 116    conf:(0.88)',
#  '213. Soil_Type=haploborolis_a Horizontal_Distance_To_Fire_Points=mid 280 ==> Label=FOUR 246    conf:(0.88)',
#  '214. Slope=slope_medium Soil_Type=moran_a 140 ==> Label=SEVEN 123    conf:(0.88)',
#  '215. Elevation=elevation_ultra Slope=slope_medium Soil_Type=moran_a 140 ==> Label=SEVEN 123    conf:(0.88)',
#  '216. Slope=slope_ultra Soil_Type=haploborolis_a 485 ==> Label=FOUR 426    conf:(0.88)',
#  '217. Soil_Type=haploborolis_a Hillshade_9am=hillshade_9am_max 606 ==> Label=FOUR 532    conf:(0.88)',
#  '218. Soil_Type=leighcan_i Hillshade_9am=hillshade_9am_min Hillshade_noon=hillnoon_max 221 ==> Label=SEVEN 194    conf:(0.88)',
#  '219. Elevation=elevation_ultra Soil_Type=leighcan_i Hillshade_9am=hillshade_9am_min Hillshade_noon=hillnoon_max 221 ==> Label=SEVEN 194    conf:(0.88)',
#  '220. Elevation=elevation_ultra Soil_Type=moran_a 499 ==> Label=SEVEN 438    conf:(0.88)',
#  '221. Slope=slope_ultra Soil_Type=como_b Horizontal_Distance_To_Fire_Points=mid 179 ==> Label=FIVE 157    conf:(0.88)',
#  '222. Slope=slope_low Soil_Type=leighcan_i 266 ==> Label=SEVEN 233    conf:(0.88)',
#  '223. Elevation=elevation_ultra Slope=slope_low Soil_Type=leighcan_i 266 ==> Label=SEVEN 233    conf:(0.88)',
#  '224. Elevation=elevation_high Soil_Type=catamount_a Hillshade_9am=hillshade_9am_max 185 ==> Label=FIVE 162    conf:(0.88)',
#  '225. Elevation=elevation_low Aspect=aspect_high Soil_Type=haploborolis_a Horizontal_Distance_To_Fire_Points=low 184 ==> Label=FOUR 161    conf:(0.88)',
#  '226. Soil_Type=legault_a 176 ==> Label=TWO 154    conf:(0.88)',
#  '227. Slope=slope_medium Soil_Type=leighcan_i 199 ==> Label=SEVEN 174    conf:(0.87)',
#  '228. Elevation=elevation_ultra Slope=slope_medium Soil_Type=leighcan_i 199 ==> Label=SEVEN 174    conf:(0.87)',
#  '229. Soil_Type=moran_a 501 ==> Label=SEVEN 438    conf:(0.87)',
#  '230. Slope=slope_low Soil_Type=leighcan_i Hillshade_noon=hillnoon_max 167 ==> Label=SEVEN 146    conf:(0.87)',
#  '231. Soil_Type=leighcan_i Hillshade_noon=hillnoon_min Horizontal_Distance_To_Fire_Points=mid 167 ==> Label=SEVEN 146    conf:(0.87)',
#  '232. Elevation=elevation_ultra Slope=slope_low Soil_Type=leighcan_i Hillshade_noon=hillnoon_max 167 ==> Label=SEVEN 146    conf:(0.87)',
#  '233. Elevation=elevation_ultra Soil_Type=leighcan_i Hillshade_noon=hillnoon_min Horizontal_Distance_To_Fire_Points=mid 167 ==> Label=SEVEN 146    conf:(0.87)',
#  '234. Soil_Type=moran_a Hillshade_noon=hillnoon_min Horizontal_Distance_To_Fire_Points=mid 246 ==> Label=SEVEN 215    conf:(0.87)',
#  '235. Aspect=aspect_medium Slope=slope_ultra Soil_Type=haploborolis_a Horizontal_Distance_To_Fire_Points=low 150 ==> Label=FOUR 131    conf:(0.87)',
#  '236. Aspect=aspect_medium Slope=slope_ultra Soil_Type=haploborolis_a Hillshade_9am=hillshade_9am_max Horizontal_Distance_To_Fire_Points=low 150 ==> Label=FOUR 131    conf:(0.87)',
#  '237. Aspect=aspect_medium Slope=slope_ultra Soil_Type=haploborolis_a Hillshade_noon=hillnoon_min Horizontal_Distance_To_Fire_Points=low 150 ==> Label=FOUR 131    conf:(0.87)',
#  '238. Aspect=aspect_medium Slope=slope_ultra Soil_Type=haploborolis_a Hillshade_9am=hillshade_9am_max Hillshade_noon=hillnoon_min Horizontal_Distance_To_Fire_Points=low 150 ==> Label=FOUR 131    conf:(0.87)',
#  '239. Aspect=aspect_high Slope=slope_ultra Soil_Type=haploborolis_a Horizontal_Distance_To_Fire_Points=low 142 ==> Label=FOUR 124    conf:(0.87)',
#  '240. Soil_Type=leighcan_i Hillshade_9am=hillshade_9am_min 418 ==> Label=SEVEN 365    conf:(0.87)',
#  '241. Elevation=elevation_ultra Soil_Type=leighcan_i Hillshade_9am=hillshade_9am_min 418 ==> Label=SEVEN 365    conf:(0.87)',
#  '242. Aspect=aspect_high Soil_Type=haploborolis_a Hillshade_9am=hillshade_9am_max 226 ==> Label=FOUR 197    conf:(0.87)',
#  '243. Elevation=elevation_low Soil_Type=haploborolis_a Hillshade_noon=hillnoon_min Horizontal_Distance_To_Fire_Points=low 365 ==> Label=FOUR 318    conf:(0.87)',
#  '244. Elevation=elevation_low Soil_Type=gateview_a Hillshade_9am=hillshade_9am_min Hillshade_noon=hillnoon_min 131 ==> Label=FOUR 114    conf:(0.87)',
#  '245. Elevation=elevation_low Soil_Type=gateview_a Hillshade_9am=hillshade_9am_min Horizontal_Distance_To_Fire_Points=low 184 ==> Label=FOUR 160    conf:(0.87)',
#  '246. Slope=slope_low Soil_Type=legault_a 130 ==> Label=TWO 113    conf:(0.87)',
#  '247. Slope=slope_low Soil_Type=leighcan_i Hillshade_9am=hillshade_9am_min 221 ==> Label=SEVEN 192    conf:(0.87)',
#  '248. Elevation=elevation_ultra Slope=slope_low Soil_Type=leighcan_i Hillshade_9am=hillshade_9am_min 221 ==> Label=SEVEN 192    conf:(0.87)',
#  '249. Elevation=elevation_low Aspect=aspect_high Soil_Type=haploborolis_a Hillshade_9am=hillshade_9am_max Horizontal_Distance_To_Fire_Points=low 152 ==> Label=FOUR 132    conf:(0.87)',
#  '250. Soil_Type=leighcan_i Hillshade_9am=hillshade_9am_min Hillshade_noon=hillnoon_min 197 ==> Label=SEVEN 171    conf:(0.87)',
#  '251. Elevation=elevation_ultra Soil_Type=leighcan_i Hillshade_9am=hillshade_9am_min Hillshade_noon=hillnoon_min 197 ==> Label=SEVEN 171    conf:(0.87)',
#  '252. Slope=slope_ultra Soil_Type=como_b Hillshade_noon=hillnoon_min 227 ==> Label=FIVE 197    conf:(0.87)',
#  '253. Slope=slope_ultra Soil_Type=haploborolis_a Horizontal_Distance_To_Fire_Points=low 295 ==> Label=FOUR 256    conf:(0.87)',
#  '254. Elevation=elevation_low Soil_Type=haploborolis_a Horizontal_Distance_To_Fire_Points=low 416 ==> Label=FOUR 361    conf:(0.87)',
#  '255. Soil_Type=leighcan_i 546 ==> Label=SEVEN 473    conf:(0.87)',
#  '256. Elevation=elevation_ultra Soil_Type=leighcan_i 546 ==> Label=SEVEN 473    conf:(0.87)',
#  '257. Elevation=elevation_low Aspect=aspect_high Slope=slope_ultra Hillshade_9am=hillshade_9am_max 186 ==> Label=FOUR 161    conf:(0.87)',
#  '258. Elevation=elevation_low Soil_Type=haploborolis_a Hillshade_9am=hillshade_9am_max Hillshade_noon=hillnoon_min Horizontal_Distance_To_Fire_Points=low 334 ==> Label=FOUR 289    conf:(0.87)',
#  '259. Elevation=elevation_ultra Soil_Type=moran_a Hillshade_9am=hillshade_9am_min Hillshade_noon=hillnoon_min 218 ==> Label=SEVEN 188    conf:(0.86)',
#  '260. Soil_Type=catamount_a Hillshade_9am=hillshade_9am_max Hillshade_noon=hillnoon_min 138 ==> Label=FIVE 119    conf:(0.86)',
#  '261. Soil_Type=como_b Hillshade_noon=hillnoon_min Horizontal_Distance_To_Fire_Points=low 152 ==> Label=FIVE 131    conf:(0.86)',
#  '262. Elevation=elevation_low Aspect=aspect_high Slope=slope_ultra Hillshade_9am=hillshade_9am_max Hillshade_noon=hillnoon_min 172 ==> Label=FOUR 148    conf:(0.86)',
#  '263. Soil_Type=como_b Horizontal_Distance_To_Fire_Points=low 184 ==> Label=FIVE 158    conf:(0.86)',
#  '264. Elevation=elevation_low Soil_Type=haploborolis_a Hillshade_9am=hillshade_9am_max Horizontal_Distance_To_Fire_Points=low 351 ==> Label=FOUR 301    conf:(0.86)',
#  '265. Elevation=elevation_low Slope=slope_low Hillshade_noon=hillnoon_min 210 ==> Label=FOUR 180    conf:(0.86)',
#  '266. Slope=slope_low Soil_Type=leighcan_i Hillshade_9am=hillshade_9am_min Hillshade_noon=hillnoon_max 147 ==> Label=SEVEN 126    conf:(0.86)',
#  '267. Elevation=elevation_ultra Slope=slope_low Soil_Type=leighcan_i Hillshade_9am=hillshade_9am_min Hillshade_noon=hillnoon_max 147 ==> Label=SEVEN 126    conf:(0.86)',
#  '268. Slope=slope_ultra Soil_Type=como_b 234 ==> Label=FIVE 200    conf:(0.85)',
#  '269. Soil_Type=moran_a Hillshade_9am=hillshade_9am_min Hillshade_noon=hillnoon_min 220 ==> Label=SEVEN 188    conf:(0.85)',
#  '270. Soil_Type=catamount_a Hillshade_9am=hillshade_9am_max 190 ==> Label=FIVE 162    conf:(0.85)',
#  '271. Elevation=elevation_low Slope=slope_low Hillshade_9am=hillshade_9am_min Hillshade_noon=hillnoon_min 176 ==> Label=FOUR 150    conf:(0.85)',
#  '272. Elevation=elevation_low Aspect=aspect_medium Soil_Type=haploborolis_a Horizontal_Distance_To_Fire_Points=low 201 ==> Label=FOUR 171    conf:(0.85)',
#  '273. Elevation=elevation_low Aspect=aspect_medium Soil_Type=haploborolis_a Hillshade_noon=hillnoon_min Horizontal_Distance_To_Fire_Points=low 200 ==> Label=FOUR 170    conf:(0.85)',
#  '274. Elevation=elevation_low Aspect=aspect_medium Soil_Type=haploborolis_a Hillshade_9am=hillshade_9am_max Horizontal_Distance_To_Fire_Points=low 198 ==> Label=FOUR 168    conf:(0.85)',
#  '275. Soil_Type=haploborolis_a Hillshade_noon=hillnoon_min Horizontal_Distance_To_Fire_Points=low 375 ==> Label=FOUR 318    conf:(0.85)',
#  '276. Elevation=elevation_low Aspect=aspect_medium Soil_Type=haploborolis_a Hillshade_9am=hillshade_9am_max Hillshade_noon=hillnoon_min Horizontal_Distance_To_Fire_Points=low 197 ==> Label=FOUR 167    conf:(0.85)',
#  '277. Soil_Type=haploborolis_a Hillshade_9am=hillshade_9am_max Hillshade_noon=hillnoon_min Horizontal_Distance_To_Fire_Points=low 341 ==> Label=FOUR 289    conf:(0.85)',
#  '278. Elevation=elevation_low Slope=slope_low Hillshade_noon=hillnoon_min Horizontal_Distance_To_Fire_Points=low 144 ==> Label=FOUR 122    conf:(0.85)',
#  '279. Elevation=elevation_low Aspect=aspect_high Hillshade_9am=hillshade_9am_max Hillshade_noon=hillnoon_min 229 ==> Label=FOUR 194    conf:(0.85)',
#  '280. Soil_Type=leighcan_i Hillshade_noon=hillnoon_min 287 ==> Label=SEVEN 243    conf:(0.85)',
#  '281. Elevation=elevation_ultra Soil_Type=leighcan_i Hillshade_noon=hillnoon_min 287 ==> Label=SEVEN 243    conf:(0.85)',
#  '282. Aspect=aspect_high Soil_Type=haploborolis_a Hillshade_9am=hillshade_9am_max Horizontal_Distance_To_Fire_Points=low 156 ==> Label=FOUR 132    conf:(0.85)',
#  '283. Elevation=elevation_low Slope=slope_low 447 ==> Label=FOUR 378    conf:(0.85)',
#  '284. Elevation=elevation_ultra Soil_Type=moran_a Horizontal_Distance_To_Fire_Points=mid 291 ==> Label=SEVEN 246    conf:(0.85)',
#  '285. Elevation=elevation_low Aspect=aspect_high Slope=slope_ultra Hillshade_noon=hillnoon_min 179 ==> Label=FOUR 151    conf:(0.84)',
#  '286. Elevation=elevation_low Slope=slope_low Hillshade_9am=hillshade_9am_min 389 ==> Label=FOUR 328    conf:(0.84)',
#  '287. Elevation=elevation_low Aspect=aspect_high Hillshade_9am=hillshade_9am_max 311 ==> Label=FOUR 262    conf:(0.84)',
#  '288. Soil_Type=leighcan_a Hillshade_9am=hillshade_9am_min 190 ==> Label=ONE 160    conf:(0.84)',
#  '289. Soil_Type=moran_a Horizontal_Distance_To_Fire_Points=mid 293 ==> Label=SEVEN 246    conf:(0.84)',
#  '290. Soil_Type=moran_b Horizontal_Distance_To_Fire_Points=mid 174 ==> Label=SEVEN 146    conf:(0.84)',
#  '291. Elevation=elevation_ultra Soil_Type=moran_b Horizontal_Distance_To_Fire_Points=mid 174 ==> Label=SEVEN 146    conf:(0.84)',
#  '292. Elevation=elevation_low Slope=slope_low Hillshade_9am=hillshade_9am_min Hillshade_noon=hillnoon_max 213 ==> Label=FOUR 178    conf:(0.84)',
#  '293. Elevation=elevation_low Slope=slope_low Hillshade_noon=hillnoon_max 237 ==> Label=FOUR 198    conf:(0.84)',
#  '294. Soil_Type=haploborolis_a 727 ==> Label=FOUR 607    conf:(0.83)',
#  '295. Elevation=elevation_low Aspect=aspect_high Hillshade_noon=hillnoon_min 236 ==> Label=FOUR 197    conf:(0.83)',
#  '296. Elevation=elevation_low Aspect=aspect_high Slope=slope_ultra Hillshade_9am=hillshade_9am_max Horizontal_Distance_To_Fire_Points=low 145 ==> Label=FOUR 121    conf:(0.83)',
#  '297. Aspect=aspect_high Slope=slope_ultra Soil_Type=haploborolis_a 199 ==> Label=FOUR 166    conf:(0.83)',
#  '298. Soil_Type=haploborolis_a Hillshade_9am=hillshade_9am_max Horizontal_Distance_To_Fire_Points=low 362 ==> Label=FOUR 301    conf:(0.83)',
#  '299. Elevation=elevation_ultra Aspect=aspect_ultra Horizontal_Distance_To_Fire_Points=high 141 ==> Label=SEVEN 117    conf:(0.83)',
#  '300. Elevation=elevation_ultra Aspect=aspect_ultra Hillshade_9am=hillshade_9am_min Horizontal_Distance_To_Fire_Points=high 141 ==> Label=SEVEN 117    conf:(0.83)',
#  '301. Elevation=elevation_low Aspect=aspect_high Slope=slope_ultra Hillshade_9am=hillshade_9am_max Hillshade_noon=hillnoon_min Horizontal_Distance_To_Fire_Points=low 135 ==> Label=FOUR 112    conf:(0.83)',
#  '302. Elevation=elevation_low Aspect=aspect_high Hillshade_9am=hillshade_9am_max Hillshade_noon=hillnoon_min Horizontal_Distance_To_Fire_Points=low 167 ==> Label=FOUR 138    conf:(0.83)',
#  '303. Elevation=elevation_low Slope=slope_ultra Hillshade_9am=hillshade_9am_max 566 ==> Label=FOUR 466    conf:(0.82)',
#  '304. Elevation=elevation_low Slope=slope_low Horizontal_Distance_To_Fire_Points=low 321 ==> Label=FOUR 264    conf:(0.82)',
#  '305. Soil_Type=leighcan_a Hillshade_noon=hillnoon_min 135 ==> Label=ONE 111    conf:(0.82)',
#  '306. Aspect=aspect_medium Soil_Type=haploborolis_a Horizontal_Distance_To_Fire_Points=low 208 ==> Label=FOUR 171    conf:(0.82)',
#  '307. Aspect=aspect_medium Soil_Type=haploborolis_a Hillshade_noon=hillnoon_min Horizontal_Distance_To_Fire_Points=low 207 ==> Label=FOUR 170    conf:(0.82)',
#  '308. Elevation=elevation_low Slope=slope_ultra Hillshade_9am=hillshade_9am_max Hillshade_noon=hillnoon_min 552 ==> Label=FOUR 453    conf:(0.82)',
#  '309. Aspect=aspect_medium Soil_Type=haploborolis_a Hillshade_9am=hillshade_9am_max Horizontal_Distance_To_Fire_Points=low 205 ==> Label=FOUR 168    conf:(0.82)',
#  '310. Elevation=elevation_low Slope=slope_low Hillshade_9am=hillshade_9am_min Horizontal_Distance_To_Fire_Points=low 277 ==> Label=FOUR 227    conf:(0.82)',
#  '311. Aspect=aspect_medium Soil_Type=haploborolis_a Hillshade_9am=hillshade_9am_max Hillshade_noon=hillnoon_min Horizontal_Distance_To_Fire_Points=low 204 ==> Label=FOUR 167    conf:(0.82)',
#  '312. Elevation=elevation_ultra Soil_Type=moran_a Hillshade_9am=hillshade_9am_min 286 ==> Label=SEVEN 234    conf:(0.82)',
#  '313. Elevation=elevation_high Soil_Type=catamount_a Horizontal_Distance_To_Fire_Points=low 152 ==> Label=FIVE 124    conf:(0.82)',
#  '314. Elevation=elevation_low Aspect=aspect_high Hillshade_9am=hillshade_9am_max Horizontal_Distance_To_Fire_Points=low 222 ==> Label=FOUR 181    conf:(0.82)',
#  '315. Soil_Type=moran_a Hillshade_9am=hillshade_9am_min 288 ==> Label=SEVEN 234    conf:(0.81)',
#  '316. Soil_Type=catamount_a Horizontal_Distance_To_Fire_Points=low 154 ==> Label=FIVE 125    conf:(0.81)',
#  '317. Elevation=elevation_low Aspect=aspect_medium Slope=slope_ultra Hillshade_9am=hillshade_9am_max 375 ==> Label=FOUR 304    conf:(0.81)',
#  '318. Elevation=elevation_low Aspect=aspect_medium Slope=slope_ultra Hillshade_9am=hillshade_9am_max Hillshade_noon=hillnoon_min 375 ==> Label=FOUR 304    conf:(0.81)',
#  '319. Elevation=elevation_low Aspect=aspect_high Hillshade_noon=hillnoon_min Horizontal_Distance_To_Fire_Points=low 174 ==> Label=FOUR 141    conf:(0.81)',
#  '320. Elevation=elevation_low Aspect=aspect_high Slope=slope_ultra Hillshade_noon=hillnoon_min Horizontal_Distance_To_Fire_Points=low 142 ==> Label=FOUR 115    conf:(0.81)',
#  '321. Aspect=aspect_medium Soil_Type=como_b Hillshade_noon=hillnoon_min 323 ==> Label=FIVE 261    conf:(0.81)',
#  '322. Soil_Type=haploborolis_a Horizontal_Distance_To_Fire_Points=low 447 ==> Label=FOUR 361    conf:(0.81)',
#  '323. Elevation=elevation_low Aspect=aspect_medium Slope=slope_ultra 377 ==> Label=FOUR 304    conf:(0.81)',
#  '324. Elevation=elevation_low Aspect=aspect_medium Slope=slope_ultra Hillshade_noon=hillnoon_min 377 ==> Label=FOUR 304    conf:(0.81)',
#  '325. Elevation=elevation_low Slope=slope_low Hillshade_9am=hillshade_9am_min Hillshade_noon=hillnoon_max Horizontal_Distance_To_Fire_Points=low 157 ==> Label=FOUR 126    conf:(0.8)',
#  '326. Elevation=elevation_low Slope=slope_low Hillshade_noon=hillnoon_max Horizontal_Distance_To_Fire_Points=low 177 ==> Label=FOUR 142    conf:(0.8)',
#  '327. Elevation=elevation_medium Aspect=aspect_high Soil_Type=ratake_a 181 ==> Label=THREE 145    conf:(0.8)',
#  '328. Aspect=aspect_medium Soil_Type=como_b Hillshade_9am=hillshade_9am_max Hillshade_noon=hillnoon_min 311 ==> Label=FIVE 249    conf:(0.8)',
#  '329. Elevation=elevation_medium Aspect=aspect_high Soil_Type=ratake_a Hillshade_noon=hillnoon_max 165 ==> Label=THREE 132    conf:(0.8)',
#  '330. Elevation=elevation_medium Aspect=aspect_ultra Slope=slope_high Hillshade_noon=hillnoon_min 169 ==> Label=SIX 135    conf:(0.8)',
# ...
#  '415. Elevation=elevation_low Hillshade_9am=hillshade_9am_max Hillshade_noon=hillnoon_min Horizontal_Distance_To_Fire_Points=low 619 ==> Label=FOUR 444    conf:(0.72)',
#  '416. Elevation=elevation_ultra Hillshade_9am=hillshade_9am_min Hillshade_noon=hillnoon_min Horizontal_Distance_To_Fire_Points=high 226 ==> Label=SEVEN 162    conf:(0.72)',
#  '417. Elevation=elevation_medium Slope=slope_high Soil_Type=bullwark_a 268 ==> Label=SIX 191    conf:(0.71)',
#  '418. Elevation=elevation_medium Soil_Type=bullwark_a Hillshade_9am=hillshade_9am_min 511 ==> Label=SIX 363    conf:(0.71)',
#  '419. Elevation=elevation_low Aspect=aspect_high Horizontal_Distance_To_Fire_Points=low 473 ==> Label=FOUR 336    conf:(0.71)',
#  '420. Elevation=elevation_medium Soil_Type=bullwark_a Hillshade_9am=hillshade_9am_min Hillshade_noon=hillnoon_min 430 ==> Label=SIX 305    conf:(0.71)',
#  '421. Elevation=elevation_ultra Hillshade_noon=hillnoon_min Horizontal_Distance_To_Fire_Points=high 344 ==> Label=SEVEN 243    conf:(0.71)',
#  '422. Elevation=elevation_low Aspect=aspect_medium Slope=slope_high 173 ==> Label=FOUR 122    conf:(0.71)',
#  '423. Elevation=elevation_low Aspect=aspect_medium Slope=slope_high Hillshade_9am=hillshade_9am_max 173 ==> Label=FOUR 122    conf:(0.71)',
#  '424. Elevation=elevation_low Aspect=aspect_medium Slope=slope_high Hillshade_noon=hillnoon_min 173 ==> Label=FOUR 122    conf:(0.71)',
#  '425. Elevation=elevation_low Aspect=aspect_medium Slope=slope_high Hillshade_9am=hillshade_9am_max Hillshade_noon=hillnoon_min 173 ==> Label=FOUR 122    conf:(0.71)',
#  '426. Elevation=elevation_high Aspect=aspect_medium Hillshade_9am=hillshade_9am_max Horizontal_Distance_To_Fire_Points=low 189 ==> Label=FIVE 133    conf:(0.7)',
#  '427. Elevation=elevation_high Hillshade_9am=hillshade_9am_max Horizontal_Distance_To_Fire_Points=low 298 ==> Label=FIVE 209    conf:(0.7)',
#  '428. Elevation=elevation_ultra Hillshade_9am=hillshade_9am_max Horizontal_Distance_To_Fire_Points=high 176 ==> Label=SEVEN 123    conf:(0.7)',
#  '429. Elevation=elevation_medium Soil_Type=bullwark_a Horizontal_Distance_To_Fire_Points=low 264 ==> Label=SIX 184    conf:(0.7)',
#  '430. Elevation=elevation_low Aspect=aspect_high Hillshade_noon=hillnoon_max 379 ==> Label=FOUR 264    conf:(0.7)',
#  '431. Elevation=elevation_medium Soil_Type=bullwark_a Hillshade_9am=hillshade_9am_min Horizontal_Distance_To_Fire_Points=mid 281 ==> Label=SIX 195    conf:(0.69)',
#  '432. Elevation=elevation_medium Soil_Type=bullwark_a Hillshade_9am=hillshade_9am_min Hillshade_noon=hillnoon_min Horizontal_Distance_To_Fire_Points=mid 258 ==> Label=SIX 179    conf:(0.69)',
#  '433. Elevation=elevation_low Aspect=aspect_medium Horizontal_Distance_To_Fire_Points=low 483 ==> Label=FOUR 335    conf:(0.69)',
#  '434. Elevation=elevation_low Aspect=aspect_high Slope=slope_ultra Horizontal_Distance_To_Fire_Points=low 238 ==> Label=FOUR 165    conf:(0.69)',
#  '435. Elevation=elevation_medium Soil_Type=bullwark_a Hillshade_noon=hillnoon_min Horizontal_Distance_To_Fire_Points=low 204 ==> Label=SIX 141    conf:(0.69)',
#  '436. Elevation=elevation_ultra Horizontal_Distance_To_Fire_Points=high 519 ==> Label=SEVEN 358    conf:(0.69)',
#  '437. Elevation=elevation_low Aspect=aspect_medium Hillshade_noon=hillnoon_min Horizontal_Distance_To_Fire_Points=low 454 ==> Label=FOUR 312    conf:(0.69)',
#  '438. Elevation=elevation_ultra Hillshade_9am=hillshade_9am_min Horizontal_Distance_To_Fire_Points=high 343 ==> Label=SEVEN 235    conf:(0.69)',
#  '439. Elevation=elevation_low Aspect=aspect_medium Hillshade_9am=hillshade_9am_max Horizontal_Distance_To_Fire_Points=low 448 ==> Label=FOUR 306    conf:(0.68)',
#  '440. Elevation=elevation_medium Soil_Type=bullwark_a 595 ==> Label=SIX 406    conf:(0.68)',
#  '441. Elevation=elevation_low Aspect=aspect_medium Hillshade_9am=hillshade_9am_max Hillshade_noon=hillnoon_min Horizontal_Distance_To_Fire_Points=low 437 ==> Label=FOUR 298    conf:(0.68)',
#  '442. Elevation=elevation_medium Soil_Type=bullwark_a Hillshade_noon=hillnoon_min 509 ==> Label=SIX 347    conf:(0.68)',
#  '443. Elevation=elevation_high Aspect=aspect_medium Horizontal_Distance_To_Fire_Points=low 204 ==> Label=FIVE 139    conf:(0.68)',
#  '444. Elevation=elevation_medium Aspect=aspect_ultra Hillshade_noon=hillnoon_min 412 ==> Label=SIX 280    conf:(0.68)',
#  '445. Elevation=elevation_medium Aspect=aspect_ultra Hillshade_9am=hillshade_9am_min Hillshade_noon=hillnoon_min 412 ==> Label=SIX 280    conf:(0.68)',
#  '446. Elevation=elevation_medium Aspect=aspect_low Soil_Type=bullwark_a Hillshade_9am=hillshade_9am_min 205 ==> Label=SIX 139    conf:(0.68)',
#  '447. Elevation=elevation_ultra Aspect=aspect_medium Slope=slope_high 180 ==> Label=SEVEN 122    conf:(0.68)',
#  '448. Elevation=elevation_ultra Aspect=aspect_medium Slope=slope_high Hillshade_9am=hillshade_9am_max 180 ==> Label=SEVEN 122    conf:(0.68)',
#  '449. Elevation=elevation_ultra Aspect=aspect_medium Slope=slope_high Hillshade_noon=hillnoon_min 180 ==> Label=SEVEN 122    conf:(0.68)',
#  '450. Elevation=elevation_ultra Aspect=aspect_medium Slope=slope_high Hillshade_9am=hillshade_9am_max Hillshade_noon=hillnoon_min 180 ==> Label=SEVEN 122    conf:(0.68)',
#  '451. Elevation=elevation_medium Aspect=aspect_low Soil_Type=bullwark_a Hillshade_9am=hillshade_9am_min Hillshade_noon=hillnoon_min 204 ==> Label=SIX 138    conf:(0.68)',
#  '452. Elevation=elevation_medium Aspect=aspect_low Soil_Type=bullwark_a 213 ==> Label=SIX 144    conf:(0.68)',
#  '453. Elevation=elevation_medium Soil_Type=bullwark_a Hillshade_noon=hillnoon_min Horizontal_Distance_To_Fire_Points=mid 305 ==> Label=SIX 206    conf:(0.68)',
#  '454. Elevation=elevation_medium Aspect=aspect_low Soil_Type=bullwark_a Hillshade_noon=hillnoon_min 212 ==> Label=SIX 143    conf:(0.67)',
#  '455. Elevation=elevation_ultra Aspect=aspect_medium Hillshade_9am=hillshade_9am_max Hillshade_noon=hillnoon_min 506 ==> Label=SEVEN 340    conf:(0.67)',
#  '456. Soil_Type=como_b 533 ==> Label=FIVE 358    conf:(0.67)',
#  '457. Elevation=elevation_medium Soil_Type=bullwark_a Horizontal_Distance_To_Fire_Points=mid 331 ==> Label=SIX 222    conf:(0.67)',
#  '458. Elevation=elevation_ultra Slope=slope_high Hillshade_9am=hillshade_9am_max 269 ==> Label=SEVEN 180    conf:(0.67)',
#  '459. Elevation=elevation_ultra Hillshade_9am=hillshade_9am_max Hillshade_noon=hillnoon_min 582 ==> Label=SEVEN 388    conf:(0.67)',
#  '460. Elevation=elevation_medium Slope=slope_high Hillshade_9am=hillshade_9am_min Hillshade_noon=hillnoon_min 323 ==> Label=SIX 215    conf:(0.67)',
#  '461. Elevation=elevation_medium Aspect=aspect_ultra Hillshade_noon=hillnoon_min Horizontal_Distance_To_Fire_Points=mid 236 ==> Label=SIX 157    conf:(0.67)',
#  '462. Elevation=elevation_medium Aspect=aspect_ultra Hillshade_9am=hillshade_9am_min Hillshade_noon=hillnoon_min Horizontal_Distance_To_Fire_Points=mid 236 ==> Label=SIX 157    conf:(0.67)',
#  '463. Elevation=elevation_ultra Slope=slope_high Hillshade_9am=hillshade_9am_max Hillshade_noon=hillnoon_min 218 ==> Label=SEVEN 145    conf:(0.67)',
#  '464. Elevation=elevation_ultra Aspect=aspect_medium Hillshade_9am=hillshade_9am_max 553 ==> Label=SEVEN 367    conf:(0.66)',
#  '465. Elevation=elevation_low Hillshade_noon=hillnoon_max 619 ==> Label=FOUR 410    conf:(0.66)',
#  '466. Aspect=aspect_ultra Slope=slope_high Soil_Type=bullwark_a Hillshade_noon=hillnoon_min 213 ==> Label=SIX 141    conf:(0.66)',
#  '467. Aspect=aspect_ultra Slope=slope_high Soil_Type=bullwark_a Hillshade_9am=hillshade_9am_min Hillshade_noon=hillnoon_min 213 ==> Label=SIX 141    conf:(0.66)',
#  '468. Elevation=elevation_ultra Aspect=aspect_medium Hillshade_noon=hillnoon_min 559 ==> Label=SEVEN 370    conf:(0.66)',
#  '469. Elevation=elevation_low Aspect=aspect_high Hillshade_9am=hillshade_9am_min Hillshade_noon=hillnoon_max 297 ==> Label=FOUR 196    conf:(0.66)',
#  '470. Soil_Type=catamount_a Hillshade_noon=hillnoon_min 214 ==> Label=FIVE 141    conf:(0.66)',
#  '471. Elevation=elevation_ultra Hillshade_noon=hillnoon_max Horizontal_Distance_To_Fire_Points=high 175 ==> Label=SEVEN 115    conf:(0.66)',
#  '472. Aspect=aspect_ultra Slope=slope_high Soil_Type=bullwark_a 258 ==> Label=SIX 169    conf:(0.66)',
#  '473. Aspect=aspect_ultra Slope=slope_high Soil_Type=bullwark_a Hillshade_9am=hillshade_9am_min 258 ==> Label=SIX 169    conf:(0.66)',
#  '474. Elevation=elevation_ultra Soil_Type=leighcan_b Hillshade_9am=hillshade_9am_min 194 ==> Label=ONE 127    conf:(0.65)',
#  '475. Elevation=elevation_low Aspect=aspect_high Hillshade_9am=hillshade_9am_min 304 ==> Label=FOUR 199    conf:(0.65)',
#  '476. Elevation=elevation_ultra Slope=slope_ultra Hillshade_noon=hillnoon_min 237 ==> Label=SEVEN 155    conf:(0.65)',
#  '477. Elevation=elevation_low Aspect=aspect_high Hillshade_noon=hillnoon_max Horizontal_Distance_To_Fire_Points=low 299 ==> Label=FOUR 195    conf:(0.65)',
#  '478. Elevation=elevation_high Slope=slope_low Horizontal_Distance_To_Fire_Points=high 172 ==> Label=TWO 112    conf:(0.65)',
#  '479. Aspect=aspect_high Slope=slope_ultra Hillshade_9am=hillshade_9am_max Hillshade_noon=hillnoon_min Horizontal_Distance_To_Fire_Points=low 172 ==> Label=FOUR 112    conf:(0.65)',
#  '480. Elevation=elevation_ultra Aspect=aspect_medium 657 ==> Label=SEVEN 427    conf:(0.65)',
#  '481. Elevation=elevation_high Soil_Type=como_a Hillshade_noon=hillnoon_max 171 ==> Label=TWO 111    conf:(0.65)',
#  '482. Elevation=elevation_medium Aspect=aspect_ultra Horizontal_Distance_To_Fire_Points=low 267 ==> Label=SIX 173    conf:(0.65)',
#  '483. Elevation=elevation_medium Aspect=aspect_ultra Hillshade_9am=hillshade_9am_min Horizontal_Distance_To_Fire_Points=low 267 ==> Label=SIX 173    conf:(0.65)',
#  '484. Elevation=elevation_medium Slope=slope_high Hillshade_9am=hillshade_9am_min Hillshade_noon=hillnoon_min Horizontal_Distance_To_Fire_Points=mid 195 ==> Label=SIX 126    conf:(0.65)',
#  '485. Elevation=elevation_ultra Hillshade_9am=hillshade_9am_max 804 ==> Label=SEVEN 519    conf:(0.65)',
#  '486. Elevation=elevation_ultra Slope=slope_high Hillshade_noon=hillnoon_min 507 ==> Label=SEVEN 327    conf:(0.64)',
#  '487. Elevation=elevation_high Soil_Type=como_b 307 ==> Label=FIVE 198    conf:(0.64)',
#  '488. Soil_Type=catamount_a 364 ==> Label=FIVE 234    conf:(0.64)',
#  '489. Elevation=elevation_ultra Soil_Type=leighcan_b 236 ==> Label=ONE 151    conf:(0.64)',
#  '490. Elevation=elevation_ultra Aspect=aspect_medium Slope=slope_medium 172 ==> Label=SEVEN 110    conf:(0.64)',
#  '491. Elevation=elevation_ultra Aspect=aspect_medium Slope=slope_medium Hillshade_9am=hillshade_9am_max 172 ==> Label=SEVEN 110    conf:(0.64)',
#  '492. Soil_Type=como_b Horizontal_Distance_To_Fire_Points=mid 302 ==> Label=FIVE 193    conf:(0.64)',
#  '493. Elevation=elevation_low Slope=slope_medium Hillshade_noon=hillnoon_min 298 ==> Label=FOUR 190    conf:(0.64)',
#  '494. Elevation=elevation_medium Slope=slope_ultra Hillshade_9am=hillshade_9am_min Hillshade_noon=hillnoon_min 211 ==> Label=SIX 134    conf:(0.64)',
#  '495. Elevation=elevation_low Slope=slope_medium 394 ==> Label=FOUR 250    conf:(0.63)',
#  '496. Elevation=elevation_low Slope=slope_ultra Hillshade_noon=hillnoon_min Horizontal_Distance_To_Fire_Points=mid 281 ==> Label=FOUR 178    conf:(0.63)',
#  '497. Elevation=elevation_low Hillshade_9am=hillshade_9am_min Hillshade_noon=hillnoon_max 522 ==> Label=FOUR 330    conf:(0.63)',
#  '498. Elevation=elevation_medium Slope=slope_high Hillshade_9am=hillshade_9am_min Horizontal_Distance_To_Fire_Points=low 187 ==> Label=SIX 118    conf:(0.63)',
#  '499. Elevation=elevation_ultra Slope=slope_medium Hillshade_9am=hillshade_9am_max Hillshade_noon=hillnoon_min 176 ==> Label=SEVEN 111    conf:(0.63)',
#  '500. Elevation=elevation_ultra Slope=slope_high Hillshade_9am=hillshade_9am_min Hillshade_noon=hillnoon_min 289 ==> Label=SEVEN 182    conf:(0.63)',
#  '501. Elevation=elevation_low Hillshade_noon=hillnoon_max Horizontal_Distance_To_Fire_Points=low 474 ==> Label=FOUR 296    conf:(0.62)',
#  '502. Elevation=elevation_ultra Slope=slope_ultra 295 ==> Label=SEVEN 184    conf:(0.62)',
#  '503. Elevation=elevation_ultra Aspect=aspect_high Hillshade_9am=hillshade_9am_max 223 ==> Label=SEVEN 139    conf:(0.62)',
#  '504. Elevation=elevation_low Aspect=aspect_high Hillshade_9am=hillshade_9am_min Hillshade_noon=hillnoon_max Horizontal_Distance_To_Fire_Points=low 244 ==> Label=FOUR 152    conf:(0.62)',
#  '505. Elevation=elevation_low Aspect=aspect_ultra Slope=slope_ultra Soil_Type=bullwark_a 322 ==> Label=THREE 200    conf:(0.62)',
#  '506. Elevation=elevation_low Aspect=aspect_ultra Slope=slope_ultra Soil_Type=bullwark_a Hillshade_9am=hillshade_9am_min 322 ==> Label=THREE 200    conf:(0.62)',
#  '507. Elevation=elevation_ultra Aspect=aspect_medium Hillshade_9am=hillshade_9am_max Hillshade_noon=hillnoon_min Horizontal_Distance_To_Fire_Points=mid 285 ==> Label=SEVEN 177    conf:(0.62)',
#  '508. Aspect=aspect_high Slope=slope_ultra Hillshade_9am=hillshade_9am_max Horizontal_Distance_To_Fire_Points=low 195 ==> Label=FOUR 121    conf:(0.62)',
#  '509. Elevation=elevation_low Slope=slope_ultra Horizontal_Distance_To_Fire_Points=mid 305 ==> Label=FOUR 189    conf:(0.62)',
#  '510. Elevation=elevation_ultra Aspect=aspect_medium Hillshade_noon=hillnoon_min Horizontal_Distance_To_Fire_Points=mid 318 ==> Label=SEVEN 197    conf:(0.62)',
#  '511. Aspect=aspect_high Slope=slope_ultra Hillshade_9am=hillshade_9am_max Hillshade_noon=hillnoon_min 244 ==> Label=FOUR 151    conf:(0.62)',
#  '512. Elevation=elevation_low Aspect=aspect_high Hillshade_9am=hillshade_9am_min Horizontal_Distance_To_Fire_Points=low 251 ==> Label=FOUR 155    conf:(0.62)',
#  '513. Elevation=elevation_low Aspect=aspect_ultra Slope=slope_ultra Soil_Type=bullwark_a Hillshade_noon=hillnoon_min 307 ==> Label=THREE 189    conf:(0.62)',
#  '514. Elevation=elevation_low Aspect=aspect_ultra Slope=slope_ultra Soil_Type=bullwark_a Hillshade_9am=hillshade_9am_min Hillshade_noon=hillnoon_min 307 ==> Label=THREE 189    conf:(0.62)',
#  '515. Aspect=aspect_high Slope=slope_ultra Hillshade_noon=hillnoon_min Horizontal_Distance_To_Fire_Points=low 187 ==> Label=FOUR 115    conf:(0.61)',
#  '516. Elevation=elevation_ultra Hillshade_9am=hillshade_9am_max Hillshade_noon=hillnoon_min Horizontal_Distance_To_Fire_Points=mid 324 ==> Label=SEVEN 199    conf:(0.61)',
#  '517. Elevation=elevation_ultra Aspect=aspect_medium Hillshade_9am=hillshade_9am_max Horizontal_Distance_To_Fire_Points=mid 308 ==> Label=SEVEN 189    conf:(0.61)',
#  '518. Elevation=elevation_high Slope=slope_high Horizontal_Distance_To_Fire_Points=low 193 ==> Label=FIVE 118    conf:(0.61)',
#  '519. Aspect=aspect_high Hillshade_9am=hillshade_9am_max Hillshade_noon=hillnoon_min Horizontal_Distance_To_Fire_Points=low 227 ==> Label=FOUR 138    conf:(0.61)',
#  '520. Slope=slope_high Soil_Type=bullwark_a Hillshade_9am=hillshade_9am_min 417 ==> Label=SIX 253    conf:(0.61)',
#  '521. Elevation=elevation_ultra Aspect=aspect_high Horizontal_Distance_To_Fire_Points=low 195 ==> Label=SEVEN 118    conf:(0.61)',
#  '522. Elevation=elevation_ultra Hillshade_noon=hillnoon_min 1715 ==> Label=SEVEN 1037    conf:(0.6)',
#  '523. Elevation=elevation_ultra Slope=slope_medium Hillshade_noon=hillnoon_min Horizontal_Distance_To_Fire_Points=mid 366 ==> Label=SEVEN 221    conf:(0.6)',
#  '524. Slope=slope_high Soil_Type=bullwark_a Hillshade_9am=hillshade_9am_min Hillshade_noon=hillnoon_min 358 ==> Label=SIX 216    conf:(0.6)',
#  '525. Elevation=elevation_ultra Slope=slope_high 667 ==> Label=SEVEN 402    conf:(0.6)',
#  '526. Slope=slope_high Soil_Type=bullwark_a Hillshade_9am=hillshade_9am_min Horizontal_Distance_To_Fire_Points=low 246 ==> Label=SIX 148    conf:(0.6)',
#  '527. Elevation=elevation_ultra Aspect=aspect_medium Horizontal_Distance_To_Fire_Points=mid 376 ==> Label=SEVEN 226    conf:(0.6)',
#  '528. Elevation=elevation_low Hillshade_9am=hillshade_9am_min Hillshade_noon=hillnoon_max Horizontal_Distance_To_Fire_Points=low 408 ==> Label=FOUR 245    conf:(0.6)',
#  '']

# %%
import re
processed_rule=[]
for string in rules:
  string=re.sub(r'[0-9]+[.]','',string)
  string=re.sub(r'[0-9]+[0-9]+','',string)
  string=string[:-9].strip()
  string=re.sub(r'[A-Za-z_]+[=]+','',string)
  processed_rule.append(string)

processed_rule=processed_rule[46:]
processed_rule
# Out:
# ['elevation_low aspect_medium haploborolis_a mid  ==> FOUR',
#  'elevation_low slope_ultra haploborolis_a mid  ==> FOUR',
#  'elevation_low aspect_medium haploborolis_a Hillshade_9hillshade_9am_max mid  ==> FOUR',
#  'elevation_low slope_ultra haploborolis_a Hillshade_9hillshade_9am_max mid  ==> FOUR',
#  'elevation_low aspect_medium haploborolis_a hillnoon_min mid  ==> FOUR',
#  'elevation_low aspect_medium haploborolis_a Hillshade_9hillshade_9am_max hillnoon_min mid  ==> FOUR',
#  'elevation_low slope_ultra haploborolis_a hillnoon_min mid  ==> FOUR',
#  'elevation_low slope_ultra haploborolis_a Hillshade_9hillshade_9am_max hillnoon_min mid  ==> FOUR',
#  'elevation_low haploborolis_a hillnoon_min mid  ==> FOUR',
#  'elevation_low haploborolis_a Hillshade_9hillshade_9am_max hillnoon_min mid  ==> FOUR',
#  'elevation_low haploborolis_a Hillshade_9hillshade_9am_max mid  ==> FOUR',
#  'elevation_low haploborolis_a mid  ==> FOUR',
#  'aspect_medium moran_a  ==> SEVEN',
#  'elevation_ultra aspect_medium moran_a  ==> SEVEN',
#  'aspect_medium moran_a Hillshade_9hillshade_9am_max  ==> SEVEN',
#  'elevation_ultra aspect_medium moran_a Hillshade_9hillshade_9am_max  ==> SEVEN',
#  'aspect_medium moran_a hillnoon_min  ==> SEVEN',
#  'elevation_ultra aspect_medium moran_a hillnoon_min  ==> SEVEN',
#  'aspect_medium moran_a Hillshade_9hillshade_9am_max hillnoon_min  ==> SEVEN',
#  'elevation_ultra aspect_medium moran_a Hillshade_9hillshade_9am_max hillnoon_min  ==> SEVEN',
#  'elevation_medium aspect_medium como_b hillnoon_min  ==> FIVE',
#  'elevation_medium aspect_medium como_b Hillshade_9hillshade_9am_max  ==> FIVE',
#  'elevation_medium aspect_medium como_b Hillshade_9hillshade_9am_max hillnoon_min  ==> FIVE',
#  'slope_ultra haploborolis_a hillnoon_min mid  ==> FOUR',
#  'slope_ultra haploborolis_a Hillshade_9hillshade_9am_max hillnoon_min mid  ==> FOUR',
#  'moran_a hillnoon_min low  ==> SEVEN',
#  'elevation_ultra moran_a hillnoon_min low  ==> SEVEN',
#  'aspect_medium slope_ultra haploborolis_a mid  ==> FOUR',
#  'aspect_medium slope_ultra haploborolis_a Hillshade_9hillshade_9am_max mid  ==> FOUR',
#  'aspect_medium slope_ultra haploborolis_a hillnoon_min mid  ==> FOUR',
#  'aspect_medium slope_ultra haploborolis_a Hillshade_9hillshade_9am_max hillnoon_min mid  ==> FOUR',
#  'slope_ultra haploborolis_a Hillshade_9hillshade_9am_max mid  ==> FOUR',
#  'elevation_medium aspect_medium como_b  ==> FIVE',
#  'moran_a Hillshade_9hillshade_9am_max mid  ==> SEVEN',
#  'elevation_ultra moran_a Hillshade_9hillshade_9am_max mid  ==> SEVEN',
#  'moran_a Hillshade_9hillshade_9am_max  ==> SEVEN',
#  'elevation_ultra moran_a Hillshade_9hillshade_9am_max  ==> SEVEN',
#  'moran_a Hillshade_9hillshade_9am_max hillnoon_min  ==> SEVEN',
#  'elevation_ultra moran_a Hillshade_9hillshade_9am_max hillnoon_min  ==> SEVEN',
#  'elevation_medium como_b Hillshade_9hillshade_9am_max hillnoon_min  ==> FIVE',
#  'haploborolis_a hillnoon_min mid  ==> FOUR',
#  'haploborolis_a Hillshade_9hillshade_9am_max hillnoon_min mid  ==> FOUR',
#  'aspect_medium haploborolis_a mid  ==> FOUR',
#  'aspect_medium haploborolis_a Hillshade_9hillshade_9am_max mid  ==> FOUR',
#  'aspect_medium haploborolis_a hillnoon_min mid  ==> FOUR',
#  'aspect_medium haploborolis_a Hillshade_9hillshade_9am_max hillnoon_min mid  ==> FOUR',
#  'elevation_low slope_ultra Hillshade_9hillshade_9am_max mid  ==> FOUR',
#  'elevation_low slope_low gateview_a Hillshade_9hillshade_9am_min  ==> FOUR',
#  'elevation_low slope_ultra Hillshade_9hillshade_9am_max hillnoon_min mid  ==> FOUR',
#  'elevation_low aspect_medium slope_ultra haploborolis_a  ==> FOUR',
#  'elevation_low aspect_medium slope_ultra haploborolis_a Hillshade_9hillshade_9am_max  ==> FOUR',
#  'elevation_low aspect_medium slope_ultra haploborolis_a hillnoon_min  ==> FOUR',
#  'elevation_low aspect_medium slope_ultra haploborolis_a Hillshade_9hillshade_9am_max hillnoon_min  ==> FOUR',
#  'aspect_ultra moran_b  ==> SEVEN',
#  'elevation_ultra aspect_ultra moran_b  ==> SEVEN',
#  'aspect_ultra moran_b Hillshade_9hillshade_9am_min  ==> SEVEN',
#  'elevation_ultra aspect_ultra moran_b Hillshade_9hillshade_9am_min  ==> SEVEN',
#  'elevation_medium como_b Hillshade_9hillshade_9am_max  ==> FIVE',
#  'haploborolis_a Hillshade_9hillshade_9am_max mid  ==> FOUR',
#  'elevation_low slope_low gateview_a  ==> FOUR',
#  'elevation_low aspect_medium slope_ultra mid  ==> FOUR',
#  'elevation_low aspect_medium slope_ultra Hillshade_9hillshade_9am_max mid  ==> FOUR',
#  'elevation_low aspect_medium slope_ultra hillnoon_min mid  ==> FOUR',
#  'elevation_low aspect_medium slope_ultra Hillshade_9hillshade_9am_max hillnoon_min mid  ==> FOUR',
#  'aspect_medium slope_ultra como_b mid  ==> FIVE',
#  'aspect_medium slope_ultra como_b hillnoon_min mid  ==> FIVE',
#  'slope_ultra como_b Hillshade_9hillshade_9am_max hillnoon_min mid  ==> FIVE',
#  'elevation_low gateview_a hillnoon_max  ==> FOUR',
#  'aspect_medium slope_ultra como_b Hillshade_9hillshade_9am_max mid  ==> FIVE',
#  'aspect_medium slope_ultra como_b Hillshade_9hillshade_9am_max hillnoon_min mid  ==> FIVE',
#  'elevation_low slope_ultra haploborolis_a Hillshade_9hillshade_9am_max hillnoon_min  ==> FOUR',
#  'elevation_low slope_ultra haploborolis_a  ==> FOUR',
#  'elevation_low slope_ultra haploborolis_a Hillshade_9hillshade_9am_max  ==> FOUR',
#  'aspect_medium slope_ultra como_b  ==> FIVE',
#  'aspect_medium slope_ultra como_b hillnoon_min  ==> FIVE',
#  'elevation_low slope_ultra haploborolis_a hillnoon_min  ==> FOUR',
#  'elevation_low gateview_a Hillshade_9hillshade_9am_min hillnoon_max  ==> FOUR',
#  'slope_ultra como_b Hillshade_9hillshade_9am_max mid  ==> FIVE',
#  'aspect_medium slope_ultra como_b Hillshade_9hillshade_9am_max  ==> FIVE',
#  'aspect_medium slope_ultra como_b Hillshade_9hillshade_9am_max hillnoon_min  ==> FIVE',
#  'moran_a low  ==> SEVEN',
#  'elevation_ultra moran_a low  ==> SEVEN',
#  'elevation_low aspect_medium Hillshade_9hillshade_9am_max mid  ==> FOUR',
#  'elevation_low aspect_medium hillnoon_min mid  ==> FOUR',
#  'elevation_low aspect_medium mid  ==> FOUR',
#  'elevation_low aspect_medium Hillshade_9hillshade_9am_max hillnoon_min mid  ==> FOUR',
#  'elevation_medium como_b hillnoon_min  ==> FIVE',
#  'moran_b Hillshade_9hillshade_9am_min hillnoon_min  ==> SEVEN',
#  'elevation_ultra moran_b Hillshade_9hillshade_9am_min hillnoon_min  ==> SEVEN',
#  'elevation_ultra slope_high moran_a hillnoon_min  ==> SEVEN',
#  'elevation_low aspect_high slope_ultra haploborolis_a  ==> FOUR',
#  'elevation_low Hillshade_9hillshade_9am_max mid  ==> FOUR',
#  'elevation_low Hillshade_9hillshade_9am_max hillnoon_min mid  ==> FOUR',
#  'aspect_high slope_ultra haploborolis_a hillnoon_min  ==> FOUR',
#  'moran_b Hillshade_9hillshade_9am_min  ==> SEVEN',
#  'elevation_ultra moran_b Hillshade_9hillshade_9am_min  ==> SEVEN',
#  'slope_high moran_a hillnoon_min  ==> SEVEN',
#  'aspect_high slope_ultra haploborolis_a Hillshade_9hillshade_9am_max hillnoon_min  ==> FOUR',
#  'elevation_low aspect_high slope_ultra haploborolis_a hillnoon_min  ==> FOUR',
#  'elevation_low aspect_high slope_ultra haploborolis_a Hillshade_9hillshade_9am_max hillnoon_min  ==> FOUR',
#  'slope_ultra como_b Hillshade_9hillshade_9am_max hillnoon_min  ==> FIVE',
#  'elevation_low aspect_high slope_ultra haploborolis_a Hillshade_9hillshade_9am_max  ==> FOUR',
#  'slope_ultra haploborolis_a Hillshade_9hillshade_9am_max hillnoon_min  ==> FOUR',
#  'elevation_low aspect_medium haploborolis_a  ==> FOUR',
#  'aspect_medium slope_ultra haploborolis_a  ==> FOUR',
#  'aspect_medium slope_ultra haploborolis_a Hillshade_9hillshade_9am_max  ==> FOUR',
#  'aspect_medium slope_ultra haploborolis_a hillnoon_min  ==> FOUR',
#  'aspect_medium slope_ultra haploborolis_a Hillshade_9hillshade_9am_max hillnoon_min  ==> FOUR',
#  'elevation_low aspect_medium haploborolis_a Hillshade_9hillshade_9am_max  ==> FOUR',
#  'elevation_low aspect_medium haploborolis_a hillnoon_min  ==> FOUR',
#  'slope_low leighcan_i mid  ==> SEVEN',
#  'elevation_ultra slope_low leighcan_i mid  ==> SEVEN',
#  'elevation_low haploborolis_a hillnoon_min  ==> FOUR',
#  'elevation_low aspect_medium haploborolis_a Hillshade_9hillshade_9am_max hillnoon_min  ==> FOUR',
#  'slope_ultra haploborolis_a hillnoon_min  ==> FOUR',
#  'leighcan_i hillnoon_max mid  ==> SEVEN',
#  'elevation_ultra leighcan_i hillnoon_max mid  ==> SEVEN',
#  'slope_ultra haploborolis_a Hillshade_9hillshade_9am_max  ==> FOUR',
#  'elevation_low haploborolis_a Hillshade_9hillshade_9am_max hillnoon_min  ==> FOUR',
#  'elevation_low aspect_high slope_ultra haploborolis_a low  ==> FOUR',
#  'aspect_high haploborolis_a hillnoon_min  ==> FOUR',
#  'leighcan_i Hillshade_9hillshade_9am_min hillnoon_min mid  ==> SEVEN',
#  'elevation_ultra leighcan_i Hillshade_9hillshade_9am_min hillnoon_min mid  ==> SEVEN',
#  'aspect_high haploborolis_a Hillshade_9hillshade_9am_max hillnoon_min  ==> FOUR',
#  'elevation_low aspect_high haploborolis_a hillnoon_min  ==> FOUR',
#  'elevation_low haploborolis_a  ==> FOUR',
#  'elevation_low aspect_high haploborolis_a Hillshade_9hillshade_9am_max hillnoon_min  ==> FOUR',
#  'slope_low leighcan_i Hillshade_9hillshade_9am_min mid  ==> SEVEN',
#  'elevation_ultra slope_low leighcan_i Hillshade_9hillshade_9am_min mid  ==> SEVEN',
#  'elevation_low gateview_a  ==> FOUR',
#  'aspect_high slope_ultra haploborolis_a Hillshade_9hillshade_9am_max  ==> FOUR',
#  'elevation_low haploborolis_a Hillshade_9hillshade_9am_max  ==> FOUR',
#  'elevation_ultra moran_a hillnoon_min  ==> SEVEN',
#  'leighcan_i Hillshade_9hillshade_9am_min mid  ==> SEVEN',
#  'elevation_ultra leighcan_i Hillshade_9hillshade_9am_min mid  ==> SEVEN',
#  'aspect_high leighcan_i hillnoon_max  ==> SEVEN',
#  'elevation_ultra aspect_high leighcan_i hillnoon_max  ==> SEVEN',
#  'slope_ultra como_b Hillshade_9hillshade_9am_max  ==> FIVE',
#  'elevation_low slope_low mid  ==> FOUR',
#  'elevation_low slope_ultra haploborolis_a low  ==> FOUR',
#  'elevation_low slope_ultra haploborolis_a Hillshade_9hillshade_9am_max hillnoon_min low  ==> FOUR',
#  'elevation_medium como_b  ==> FIVE',
#  'elevation_low aspect_medium slope_ultra haploborolis_a low  ==> FOUR',
#  'elevation_low aspect_medium slope_ultra haploborolis_a Hillshade_9hillshade_9am_max low  ==> FOUR',
#  'elevation_low aspect_medium slope_ultra haploborolis_a hillnoon_min low  ==> FOUR',
#  'elevation_low aspect_medium slope_ultra haploborolis_a Hillshade_9hillshade_9am_max hillnoon_min low  ==> FOUR',
#  'elevation_low gateview_a Hillshade_9hillshade_9am_min  ==> FOUR',
#  'elevation_low slope_ultra haploborolis_a Hillshade_9hillshade_9am_max low  ==> FOUR',
#  'moran_a hillnoon_min  ==> SEVEN',
#  'elevation_low slope_ultra haploborolis_a hillnoon_min low  ==> FOUR',
#  'moran_b  ==> SEVEN',
#  'elevation_ultra moran_b  ==> SEVEN',
#  'aspect_high leighcan_i  ==> SEVEN',
#  'elevation_ultra aspect_high leighcan_i  ==> SEVEN',
#  'moran_b hillnoon_min  ==> SEVEN',
#  'elevation_ultra moran_b hillnoon_min  ==> SEVEN',
#  'elevation_low aspect_high haploborolis_a  ==> FOUR',
#  'elevation_ultra slope_high moran_a  ==> SEVEN',
#  'slope_ultra haploborolis_a mid  ==> FOUR',
#  'aspect_high leighcan_i Hillshade_9hillshade_9am_min  ==> SEVEN',
#  'elevation_ultra aspect_high leighcan_i Hillshade_9hillshade_9am_min  ==> SEVEN',
#  'aspect_high leighcan_i Hillshade_9hillshade_9am_min hillnoon_max  ==> SEVEN',
#  'elevation_ultra aspect_high leighcan_i Hillshade_9hillshade_9am_min hillnoon_max  ==> SEVEN',
#  'como_b Hillshade_9hillshade_9am_max low  ==> FIVE',
#  'elevation_low aspect_high haploborolis_a Hillshade_9hillshade_9am_max  ==> FOUR',
#  'aspect_ultra leighcan_i  ==> SEVEN',
#  'elevation_ultra aspect_ultra leighcan_i  ==> SEVEN',
#  'aspect_ultra leighcan_i Hillshade_9hillshade_9am_min  ==> SEVEN',
#  'elevation_ultra aspect_ultra leighcan_i Hillshade_9hillshade_9am_min  ==> SEVEN',
#  'como_b Hillshade_9hillshade_9am_max hillnoon_min low  ==> FIVE',
#  'slope_medium leighcan_i Hillshade_9hillshade_9am_min  ==> SEVEN',
#  'elevation_ultra slope_medium leighcan_i Hillshade_9hillshade_9am_min  ==> SEVEN',
#  'aspect_high haploborolis_a hillnoon_min low  ==> FOUR',
#  'elevation_low aspect_high haploborolis_a hillnoon_min low  ==> FOUR',
#  'leighcan_i mid  ==> SEVEN',
#  'elevation_ultra leighcan_i mid  ==> SEVEN',
#  'haploborolis_a Hillshade_9hillshade_9am_max hillnoon_min  ==> FOUR',
#  'slope_high moran_a  ==> SEVEN',
#  'aspect_high haploborolis_a Hillshade_9hillshade_9am_max hillnoon_min low  ==> FOUR',
#  'elevation_low aspect_high haploborolis_a Hillshade_9hillshade_9am_max hillnoon_min low  ==> FOUR',
#  'haploborolis_a hillnoon_min  ==> FOUR',
#  'leighcan_i hillnoon_max  ==> SEVEN',
#  'elevation_ultra leighcan_i hillnoon_max  ==> SEVEN',
#  'slope_ultra haploborolis_a Hillshade_9hillshade_9am_max hillnoon_min low  ==> FOUR',
#  'slope_ultra como_b hillnoon_min mid  ==> FIVE',
#  'elevation_ultra aspect_low moran_a  ==> SEVEN',
#  'elevation_low aspect_low slope_low  ==> FOUR',
#  'elevation_ultra aspect_low moran_a hillnoon_min  ==> SEVEN',
#  'elevation_low aspect_low slope_low Hillshade_9hillshade_9am_min  ==> FOUR',
#  'elevation_ultra aspect_low moran_a Hillshade_9hillshade_9am_min  ==> SEVEN',
#  'elevation_ultra aspect_low moran_a Hillshade_9hillshade_9am_min hillnoon_min  ==> SEVEN',
#  'moran_b Hillshade_9hillshade_9am_min mid  ==> SEVEN',
#  'elevation_ultra moran_b Hillshade_9hillshade_9am_min mid  ==> SEVEN',
#  'aspect_medium haploborolis_a  ==> FOUR',
#  'slope_ultra haploborolis_a Hillshade_9hillshade_9am_max low  ==> FOUR',
#  'slope_ultra haploborolis_a hillnoon_min low  ==> FOUR',
#  'elevation_high catamount_a Hillshade_9hillshade_9am_max hillnoon_min  ==> FIVE',
#  'aspect_medium haploborolis_a Hillshade_9hillshade_9am_max  ==> FOUR',
#  'aspect_medium haploborolis_a hillnoon_min  ==> FOUR',
#  'elevation_ultra moran_a hillnoon_min mid  ==> SEVEN',
#  'elevation_low gateview_a hillnoon_min  ==> FOUR',
#  'aspect_low moran_a  ==> SEVEN',
#  'elevation_low aspect_high mid  ==> FOUR',
#  'aspect_low moran_a hillnoon_min  ==> SEVEN',
#  'aspect_medium haploborolis_a Hillshade_9hillshade_9am_max hillnoon_min  ==> FOUR',
#  'elevation_low gateview_a low  ==> FOUR',
#  'aspect_low moran_a Hillshade_9hillshade_9am_min  ==> SEVEN',
#  'aspect_low moran_a Hillshade_9hillshade_9am_min hillnoon_min  ==> SEVEN',
#  'haploborolis_a mid  ==> FOUR',
#  'slope_medium moran_a  ==> SEVEN',
#  'elevation_ultra slope_medium moran_a  ==> SEVEN',
#  'slope_ultra haploborolis_a  ==> FOUR',
#  'haploborolis_a Hillshade_9hillshade_9am_max  ==> FOUR',
#  'leighcan_i Hillshade_9hillshade_9am_min hillnoon_max  ==> SEVEN',
#  'elevation_ultra leighcan_i Hillshade_9hillshade_9am_min hillnoon_max  ==> SEVEN',
#  'elevation_ultra moran_a  ==> SEVEN',
#  'slope_ultra como_b mid  ==> FIVE',
#  'slope_low leighcan_i  ==> SEVEN',
#  'elevation_ultra slope_low leighcan_i  ==> SEVEN',
#  'elevation_high catamount_a Hillshade_9hillshade_9am_max  ==> FIVE',
#  'elevation_low aspect_high haploborolis_a low  ==> FOUR',
#  'legault_a  ==> TWO',
#  'slope_medium leighcan_i  ==> SEVEN',
#  'elevation_ultra slope_medium leighcan_i  ==> SEVEN',
#  'moran_a  ==> SEVEN',
#  'slope_low leighcan_i hillnoon_max  ==> SEVEN',
#  'leighcan_i hillnoon_min mid  ==> SEVEN',
#  'elevation_ultra slope_low leighcan_i hillnoon_max  ==> SEVEN',
#  'elevation_ultra leighcan_i hillnoon_min mid  ==> SEVEN',
#  'moran_a hillnoon_min mid  ==> SEVEN',
#  'aspect_medium slope_ultra haploborolis_a low  ==> FOUR',
#  'aspect_medium slope_ultra haploborolis_a Hillshade_9hillshade_9am_max low  ==> FOUR',
#  'aspect_medium slope_ultra haploborolis_a hillnoon_min low  ==> FOUR',
#  'aspect_medium slope_ultra haploborolis_a Hillshade_9hillshade_9am_max hillnoon_min low  ==> FOUR',
#  'aspect_high slope_ultra haploborolis_a low  ==> FOUR',
#  'leighcan_i Hillshade_9hillshade_9am_min  ==> SEVEN',
#  'elevation_ultra leighcan_i Hillshade_9hillshade_9am_min  ==> SEVEN',
#  'aspect_high haploborolis_a Hillshade_9hillshade_9am_max  ==> FOUR',
#  'elevation_low haploborolis_a hillnoon_min low  ==> FOUR',
#  'elevation_low gateview_a Hillshade_9hillshade_9am_min hillnoon_min  ==> FOUR',
#  'elevation_low gateview_a Hillshade_9hillshade_9am_min low  ==> FOUR',
#  'slope_low legault_a  ==> TWO',
#  'slope_low leighcan_i Hillshade_9hillshade_9am_min  ==> SEVEN',
#  'elevation_ultra slope_low leighcan_i Hillshade_9hillshade_9am_min  ==> SEVEN',
#  'elevation_low aspect_high haploborolis_a Hillshade_9hillshade_9am_max low  ==> FOUR',
#  'leighcan_i Hillshade_9hillshade_9am_min hillnoon_min  ==> SEVEN',
#  'elevation_ultra leighcan_i Hillshade_9hillshade_9am_min hillnoon_min  ==> SEVEN',
#  'slope_ultra como_b hillnoon_min  ==> FIVE',
#  'slope_ultra haploborolis_a low  ==> FOUR',
#  'elevation_low haploborolis_a low  ==> FOUR',
#  'leighcan_i  ==> SEVEN',
#  'elevation_ultra leighcan_i  ==> SEVEN',
#  'elevation_low aspect_high slope_ultra Hillshade_9hillshade_9am_max  ==> FOUR',
#  'elevation_low haploborolis_a Hillshade_9hillshade_9am_max hillnoon_min low  ==> FOUR',
#  'elevation_ultra moran_a Hillshade_9hillshade_9am_min hillnoon_min  ==> SEVEN',
#  'catamount_a Hillshade_9hillshade_9am_max hillnoon_min  ==> FIVE',
#  'como_b hillnoon_min low  ==> FIVE',
#  'elevation_low aspect_high slope_ultra Hillshade_9hillshade_9am_max hillnoon_min  ==> FOUR',
#  'como_b low  ==> FIVE',
#  'elevation_low haploborolis_a Hillshade_9hillshade_9am_max low  ==> FOUR',
#  'elevation_low slope_low hillnoon_min  ==> FOUR',
#  'slope_low leighcan_i Hillshade_9hillshade_9am_min hillnoon_max  ==> SEVEN',
#  'elevation_ultra slope_low leighcan_i Hillshade_9hillshade_9am_min hillnoon_max  ==> SEVEN',
#  'slope_ultra como_b  ==> FIVE',
#  'moran_a Hillshade_9hillshade_9am_min hillnoon_min  ==> SEVEN',
#  'catamount_a Hillshade_9hillshade_9am_max  ==> FIVE',
#  'elevation_low slope_low Hillshade_9hillshade_9am_min hillnoon_min  ==> FOUR',
#  'elevation_low aspect_medium haploborolis_a low  ==> FOUR',
#  'elevation_low aspect_medium haploborolis_a hillnoon_min low  ==> FOUR',
#  'elevation_low aspect_medium haploborolis_a Hillshade_9hillshade_9am_max low  ==> FOUR',
#  'haploborolis_a hillnoon_min low  ==> FOUR',
#  'elevation_low aspect_medium haploborolis_a Hillshade_9hillshade_9am_max hillnoon_min low  ==> FOUR',
#  'haploborolis_a Hillshade_9hillshade_9am_max hillnoon_min low  ==> FOUR',
#  'elevation_low slope_low hillnoon_min low  ==> FOUR',
#  'elevation_low aspect_high Hillshade_9hillshade_9am_max hillnoon_min  ==> FOUR',
#  'leighcan_i hillnoon_min  ==> SEVEN',
#  'elevation_ultra leighcan_i hillnoon_min  ==> SEVEN',
#  'aspect_high haploborolis_a Hillshade_9hillshade_9am_max low  ==> FOUR',
#  'elevation_low slope_low  ==> FOUR',
#  'elevation_ultra moran_a mid  ==> SEVEN',
#  'elevation_low aspect_high slope_ultra hillnoon_min  ==> FOUR',
#  'elevation_low slope_low Hillshade_9hillshade_9am_min  ==> FOUR',
#  'elevation_low aspect_high Hillshade_9hillshade_9am_max  ==> FOUR',
#  'leighcan_a Hillshade_9hillshade_9am_min  ==> ONE',
#  'moran_a mid  ==> SEVEN',
#  'moran_b mid  ==> SEVEN',
#  'elevation_ultra moran_b mid  ==> SEVEN',
#  'elevation_low slope_low Hillshade_9hillshade_9am_min hillnoon_max  ==> FOUR',
#  'elevation_low slope_low hillnoon_max  ==> FOUR',
#  'haploborolis_a  ==> FOUR',
#  'elevation_low aspect_high hillnoon_min  ==> FOUR',
#  'elevation_low aspect_high slope_ultra Hillshade_9hillshade_9am_max low  ==> FOUR',
#  'aspect_high slope_ultra haploborolis_a  ==> FOUR',
#  'haploborolis_a Hillshade_9hillshade_9am_max low  ==> FOUR',
#  'elevation_ultra aspect_ultra high  ==> SEVEN',
#  'elevation_ultra aspect_ultra Hillshade_9hillshade_9am_min high  ==> SEVEN',
#  'elevation_low aspect_high slope_ultra Hillshade_9hillshade_9am_max hillnoon_min low  ==> FOUR',
#  'elevation_low aspect_high Hillshade_9hillshade_9am_max hillnoon_min low  ==> FOUR',
#  'elevation_low slope_ultra Hillshade_9hillshade_9am_max  ==> FOUR',
#  'elevation_low slope_low low  ==> FOUR',
#  'leighcan_a hillnoon_min  ==> ONE',
#  'aspect_medium haploborolis_a low  ==> FOUR',
#  'aspect_medium haploborolis_a hillnoon_min low  ==> FOUR',
#  'elevation_low slope_ultra Hillshade_9hillshade_9am_max hillnoon_min  ==> FOUR',
#  'aspect_medium haploborolis_a Hillshade_9hillshade_9am_max low  ==> FOUR',
#  'elevation_low slope_low Hillshade_9hillshade_9am_min low  ==> FOUR',
#  'aspect_medium haploborolis_a Hillshade_9hillshade_9am_max hillnoon_min low  ==> FOUR',
#  'elevation_ultra moran_a Hillshade_9hillshade_9am_min  ==> SEVEN',
#  'elevation_high catamount_a low  ==> FIVE',
#  'elevation_low aspect_high Hillshade_9hillshade_9am_max low  ==> FOUR',
#  'moran_a Hillshade_9hillshade_9am_min  ==> SEVEN',
#  'catamount_a low  ==> FIVE',
#  'elevation_low aspect_medium slope_ultra Hillshade_9hillshade_9am_max  ==> FOUR',
#  'elevation_low aspect_medium slope_ultra Hillshade_9hillshade_9am_max hillnoon_min  ==> FOUR',
#  'elevation_low aspect_high hillnoon_min low  ==> FOUR',
#  'elevation_low aspect_high slope_ultra hillnoon_min low  ==> FOUR',
#  'aspect_medium como_b hillnoon_min  ==> FIVE',
#  'haploborolis_a low  ==> FOUR',
#  'elevation_low aspect_medium slope_ultra  ==> FOUR',
#  'elevation_low aspect_medium slope_ultra hillnoon_min  ==> FOUR',
#  'elevation_low slope_low Hillshade_9hillshade_9am_min hillnoon_max low  ==> FOUR',
#  'elevation_low slope_low hillnoon_max low  ==> FOUR',
#  'elevation_medium aspect_high ratake_a  ==> THREE',
#  'aspect_medium como_b Hillshade_9hillshade_9am_max hillnoon_min  ==> FIVE',
#  'elevation_medium aspect_high ratake_a hillnoon_max  ==> THREE',
#  'elevation_medium aspect_ultra slope_high hillnoon_min  ==> SIX',
#  'elevation_medium aspect_ultra slope_high Hillshade_9hillshade_9am_min hillnoon_min  ==> SIX',
#  'aspect_medium como_b  ==> FIVE',
#  'aspect_medium como_b Hillshade_9hillshade_9am_max  ==> FIVE',
#  'aspect_high haploborolis_a low  ==> FOUR',
#  'como_b Hillshade_9hillshade_9am_max hillnoon_min  ==> FIVE',
#  'elevation_high aspect_medium como_b hillnoon_min  ==> FIVE',
#  'elevation_low Hillshade_9hillshade_9am_max  ==> FOUR',
#  'elevation_low Hillshade_9hillshade_9am_max hillnoon_min  ==> FOUR',
#  'elevation_low hillnoon_max mid  ==> FOUR',
#  'aspect_medium como_b hillnoon_min mid  ==> FIVE',
#  'elevation_medium ratake_a hillnoon_max  ==> THREE',
#  'elevation_high aspect_medium como_b  ==> FIVE',
#  'elevation_high aspect_medium como_b Hillshade_9hillshade_9am_max hillnoon_min  ==> FIVE',
#  'elevation_low aspect_medium  ==> FOUR',
#  'elevation_medium aspect_ultra slope_high bullwark_a  ==> SIX',
#  'elevation_medium aspect_ultra slope_high bullwark_a Hillshade_9hillshade_9am_min  ==> SIX',
#  'aspect_high haploborolis_a  ==> FOUR',
#  'elevation_high aspect_medium slope_ultra  ==> FIVE',
#  'elevation_high aspect_medium slope_ultra hillnoon_min  ==> FIVE',
#  'elevation_low aspect_medium hillnoon_min  ==> FOUR',
#  'elevation_high aspect_medium como_b Hillshade_9hillshade_9am_max  ==> FIVE',
#  'elevation_low aspect_medium Hillshade_9hillshade_9am_max  ==> FOUR',
#  'leighcan_a  ==> ONE',
#  'como_b Hillshade_9hillshade_9am_max hillnoon_min mid  ==> FIVE',
#  'elevation_low aspect_medium Hillshade_9hillshade_9am_max hillnoon_min  ==> FOUR',
#  'elevation_high catamount_a hillnoon_min  ==> FIVE',
#  'elevation_medium slope_high bullwark_a Hillshade_9hillshade_9am_min hillnoon_min  ==> SIX',
#  'aspect_medium como_b Hillshade_9hillshade_9am_max hillnoon_min mid  ==> FIVE',
#  'aspect_medium como_b mid  ==> FIVE',
#  'elevation_high aspect_medium slope_ultra Hillshade_9hillshade_9am_max  ==> FIVE',
#  'elevation_high aspect_medium slope_ultra Hillshade_9hillshade_9am_max hillnoon_min  ==> FIVE',
#  'aspect_medium como_b Hillshade_9hillshade_9am_max mid  ==> FIVE',
#  'como_b Hillshade_9hillshade_9am_max  ==> FIVE',
#  'elevation_high como_b Hillshade_9hillshade_9am_max hillnoon_min  ==> FIVE',
#  'gateview_a low  ==> FOUR',
#  'elevation_ultra Hillshade_9hillshade_9am_max low  ==> SEVEN',
#  'elevation_ultra moran_a Hillshade_9hillshade_9am_min mid  ==> SEVEN',
#  'gateview_a Hillshade_9hillshade_9am_min low  ==> FOUR',
#  'elevation_low slope_ultra Hillshade_9hillshade_9am_max low  ==> FOUR',
#  'elevation_low slope_ultra Hillshade_9hillshade_9am_max hillnoon_min low  ==> FOUR',
#  'elevation_high slope_ultra Hillshade_9hillshade_9am_max hillnoon_min mid  ==> FIVE',
#  'elevation_low slope_high mid  ==> FOUR',
#  'moran_a Hillshade_9hillshade_9am_min mid  ==> SEVEN',
#  'elevation_low aspect_high slope_high  ==> FOUR',
#  'elevation_medium slope_high bullwark_a Hillshade_9hillshade_9am_min  ==> SIX',
#  'elevation_low aspect_high  ==> FOUR',
#  'elevation_high slope_ultra Hillshade_9hillshade_9am_max hillnoon_min  ==> FIVE',
#  'elevation_ultra leighcan_a  ==> ONE',
#  'elevation_low slope_high hillnoon_min mid  ==> FOUR',
#  'elevation_medium aspect_ultra bullwark_a hillnoon_min  ==> SIX',
#  'elevation_medium aspect_ultra bullwark_a Hillshade_9hillshade_9am_min hillnoon_min  ==> SIX',
#  'elevation_medium ratake_a  ==> THREE',
#  'como_b Hillshade_9hillshade_9am_max mid  ==> FIVE',
#  'elevation_low mid  ==> FOUR',
#  'como_b hillnoon_min  ==> FIVE',
#  'elevation_low slope_high Hillshade_9hillshade_9am_max  ==> FOUR',
#  'elevation_medium aspect_ultra slope_high  ==> SIX',
#  'elevation_medium aspect_ultra slope_high Hillshade_9hillshade_9am_min  ==> SIX',
#  'elevation_medium bullwark_a Hillshade_9hillshade_9am_min hillnoon_min low  ==> SIX',
#  'elevation_medium aspect_ultra hillnoon_min low  ==> SIX',
#  'elevation_medium aspect_ultra Hillshade_9hillshade_9am_min hillnoon_min low  ==> SIX',
#  'elevation_medium aspect_ultra bullwark_a  ==> SIX',
#  'elevation_medium aspect_ultra bullwark_a Hillshade_9hillshade_9am_min  ==> SIX',
#  'elevation_medium bullwark_a Hillshade_9hillshade_9am_min low  ==> SIX',
#  'elevation_low aspect_medium slope_ultra Hillshade_9hillshade_9am_max low  ==> FOUR',
#  'elevation_low aspect_medium slope_ultra Hillshade_9hillshade_9am_max hillnoon_min low  ==> FOUR',
#  'elevation_high hillnoon_max high  ==> TWO',
#  'elevation_medium slope_high bullwark_a hillnoon_min  ==> SIX',
#  'elevation_low aspect_high slope_ultra  ==> FOUR',
#  'elevation_high como_b hillnoon_min  ==> FIVE',
#  'elevation_low slope_high Hillshade_9hillshade_9am_max hillnoon_min  ==> FOUR',
#  'elevation_high slope_ultra Hillshade_9hillshade_9am_max mid  ==> FIVE',
#  'elevation_low hillnoon_min mid  ==> FOUR',
#  'elevation_high aspect_medium Hillshade_9hillshade_9am_max hillnoon_min low  ==> FIVE',
#  'elevation_low Hillshade_9hillshade_9am_max low  ==> FOUR',
#  'elevation_high aspect_medium hillnoon_min low  ==> FIVE',
#  'elevation_high slope_ultra Hillshade_9hillshade_9am_max  ==> FIVE',
#  'elevation_high catamount_a  ==> FIVE',
#  'elevation_low aspect_medium slope_ultra low  ==> FOUR',
#  'elevation_low aspect_medium slope_ultra hillnoon_min low  ==> FOUR',
#  'elevation_high Hillshade_9hillshade_9am_max hillnoon_min low  ==> FIVE',
#  'elevation_medium ratake_a mid  ==> THREE',
#  'como_b hillnoon_min mid  ==> FIVE',
#  'elevation_high como_b Hillshade_9hillshade_9am_max  ==> FIVE',
#  'elevation_low Hillshade_9hillshade_9am_max hillnoon_min low  ==> FOUR',
#  'elevation_ultra Hillshade_9hillshade_9am_min hillnoon_min high  ==> SEVEN',
#  'elevation_medium slope_high bullwark_a  ==> SIX',
#  'elevation_medium bullwark_a Hillshade_9hillshade_9am_min  ==> SIX',
#  'elevation_low aspect_high low  ==> FOUR',
#  'elevation_medium bullwark_a Hillshade_9hillshade_9am_min hillnoon_min  ==> SIX',
#  'elevation_ultra hillnoon_min high  ==> SEVEN',
#  'elevation_low aspect_medium slope_high  ==> FOUR',
#  'elevation_low aspect_medium slope_high Hillshade_9hillshade_9am_max  ==> FOUR',
#  'elevation_low aspect_medium slope_high hillnoon_min  ==> FOUR',
#  'elevation_low aspect_medium slope_high Hillshade_9hillshade_9am_max hillnoon_min  ==> FOUR',
#  'elevation_high aspect_medium Hillshade_9hillshade_9am_max low  ==> FIVE',
#  'elevation_high Hillshade_9hillshade_9am_max low  ==> FIVE',
#  'elevation_ultra Hillshade_9hillshade_9am_max high  ==> SEVEN',
#  'elevation_medium bullwark_a low  ==> SIX',
#  'elevation_low aspect_high hillnoon_max  ==> FOUR',
#  'elevation_medium bullwark_a Hillshade_9hillshade_9am_min mid  ==> SIX',
#  'elevation_medium bullwark_a Hillshade_9hillshade_9am_min hillnoon_min mid  ==> SIX',
#  'elevation_low aspect_medium low  ==> FOUR',
#  'elevation_low aspect_high slope_ultra low  ==> FOUR',
#  'elevation_medium bullwark_a hillnoon_min low  ==> SIX',
#  'elevation_ultra high  ==> SEVEN',
#  'elevation_low aspect_medium hillnoon_min low  ==> FOUR',
#  'elevation_ultra Hillshade_9hillshade_9am_min high  ==> SEVEN',
#  'elevation_low aspect_medium Hillshade_9hillshade_9am_max low  ==> FOUR',
#  'elevation_medium bullwark_a  ==> SIX',
#  'elevation_low aspect_medium Hillshade_9hillshade_9am_max hillnoon_min low  ==> FOUR',
#  'elevation_medium bullwark_a hillnoon_min  ==> SIX',
#  'elevation_high aspect_medium low  ==> FIVE',
#  'elevation_medium aspect_ultra hillnoon_min  ==> SIX',
#  'elevation_medium aspect_ultra Hillshade_9hillshade_9am_min hillnoon_min  ==> SIX',
#  'elevation_medium aspect_low bullwark_a Hillshade_9hillshade_9am_min  ==> SIX',
#  'elevation_ultra aspect_medium slope_high  ==> SEVEN',
#  'elevation_ultra aspect_medium slope_high Hillshade_9hillshade_9am_max  ==> SEVEN',
#  'elevation_ultra aspect_medium slope_high hillnoon_min  ==> SEVEN',
#  'elevation_ultra aspect_medium slope_high Hillshade_9hillshade_9am_max hillnoon_min  ==> SEVEN',
#  'elevation_medium aspect_low bullwark_a Hillshade_9hillshade_9am_min hillnoon_min  ==> SIX',
#  'elevation_medium aspect_low bullwark_a  ==> SIX',
#  'elevation_medium bullwark_a hillnoon_min mid  ==> SIX',
#  'elevation_medium aspect_low bullwark_a hillnoon_min  ==> SIX',
#  'elevation_ultra aspect_medium Hillshade_9hillshade_9am_max hillnoon_min  ==> SEVEN',
#  'como_b  ==> FIVE',
#  'elevation_medium bullwark_a mid  ==> SIX',
#  'elevation_ultra slope_high Hillshade_9hillshade_9am_max  ==> SEVEN',
#  'elevation_ultra Hillshade_9hillshade_9am_max hillnoon_min  ==> SEVEN',
#  'elevation_medium slope_high Hillshade_9hillshade_9am_min hillnoon_min  ==> SIX',
#  'elevation_medium aspect_ultra hillnoon_min mid  ==> SIX',
#  'elevation_medium aspect_ultra Hillshade_9hillshade_9am_min hillnoon_min mid  ==> SIX',
#  'elevation_ultra slope_high Hillshade_9hillshade_9am_max hillnoon_min  ==> SEVEN',
#  'elevation_ultra aspect_medium Hillshade_9hillshade_9am_max  ==> SEVEN',
#  'elevation_low hillnoon_max  ==> FOUR',
#  'aspect_ultra slope_high bullwark_a hillnoon_min  ==> SIX',
#  'aspect_ultra slope_high bullwark_a Hillshade_9hillshade_9am_min hillnoon_min  ==> SIX',
#  'elevation_ultra aspect_medium hillnoon_min  ==> SEVEN',
#  'elevation_low aspect_high Hillshade_9hillshade_9am_min hillnoon_max  ==> FOUR',
#  'catamount_a hillnoon_min  ==> FIVE',
#  'elevation_ultra hillnoon_max high  ==> SEVEN',
#  'aspect_ultra slope_high bullwark_a  ==> SIX',
#  'aspect_ultra slope_high bullwark_a Hillshade_9hillshade_9am_min  ==> SIX',
#  'elevation_ultra leighcan_b Hillshade_9hillshade_9am_min  ==> ONE',
#  'elevation_low aspect_high Hillshade_9hillshade_9am_min  ==> FOUR',
#  'elevation_ultra slope_ultra hillnoon_min  ==> SEVEN',
#  'elevation_low aspect_high hillnoon_max low  ==> FOUR',
#  'elevation_high slope_low high  ==> TWO',
#  'aspect_high slope_ultra Hillshade_9hillshade_9am_max hillnoon_min low  ==> FOUR',
#  'elevation_ultra aspect_medium  ==> SEVEN',
#  'elevation_high como_a hillnoon_max  ==> TWO',
#  'elevation_medium aspect_ultra low  ==> SIX',
#  'elevation_medium aspect_ultra Hillshade_9hillshade_9am_min low  ==> SIX',
#  'elevation_medium slope_high Hillshade_9hillshade_9am_min hillnoon_min mid  ==> SIX',
#  'elevation_ultra Hillshade_9hillshade_9am_max  ==> SEVEN',
#  'elevation_ultra slope_high hillnoon_min  ==> SEVEN',
#  'elevation_high como_b  ==> FIVE',
#  'catamount_a  ==> FIVE',
#  'elevation_ultra leighcan_b  ==> ONE',
#  'elevation_ultra aspect_medium slope_medium  ==> SEVEN',
#  'elevation_ultra aspect_medium slope_medium Hillshade_9hillshade_9am_max  ==> SEVEN',
#  'como_b mid  ==> FIVE',
#  'elevation_low slope_medium hillnoon_min  ==> FOUR',
#  'elevation_medium slope_ultra Hillshade_9hillshade_9am_min hillnoon_min  ==> SIX',
#  'elevation_low slope_medium  ==> FOUR',
#  'elevation_low slope_ultra hillnoon_min mid  ==> FOUR',
#  'elevation_low Hillshade_9hillshade_9am_min hillnoon_max  ==> FOUR',
#  'elevation_medium slope_high Hillshade_9hillshade_9am_min low  ==> SIX',
#  'elevation_ultra slope_medium Hillshade_9hillshade_9am_max hillnoon_min  ==> SEVEN',
#  'elevation_ultra slope_high Hillshade_9hillshade_9am_min hillnoon_min  ==> SEVEN',
#  'elevation_low hillnoon_max low  ==> FOUR',
#  'elevation_ultra slope_ultra  ==> SEVEN',
#  'elevation_ultra aspect_high Hillshade_9hillshade_9am_max  ==> SEVEN',
#  'elevation_low aspect_high Hillshade_9hillshade_9am_min hillnoon_max low  ==> FOUR',
#  'elevation_low aspect_ultra slope_ultra bullwark_a  ==> THREE',
#  'elevation_low aspect_ultra slope_ultra bullwark_a Hillshade_9hillshade_9am_min  ==> THREE',
#  'elevation_ultra aspect_medium Hillshade_9hillshade_9am_max hillnoon_min mid  ==> SEVEN',
#  'aspect_high slope_ultra Hillshade_9hillshade_9am_max low  ==> FOUR',
#  'elevation_low slope_ultra mid  ==> FOUR',
#  'elevation_ultra aspect_medium hillnoon_min mid  ==> SEVEN',
#  'aspect_high slope_ultra Hillshade_9hillshade_9am_max hillnoon_min  ==> FOUR',
#  'elevation_low aspect_high Hillshade_9hillshade_9am_min low  ==> FOUR',
#  'elevation_low aspect_ultra slope_ultra bullwark_a hillnoon_min  ==> THREE',
#  'elevation_low aspect_ultra slope_ultra bullwark_a Hillshade_9hillshade_9am_min hillnoon_min  ==> THREE',
#  'aspect_high slope_ultra hillnoon_min low  ==> FOUR',
#  'elevation_ultra Hillshade_9hillshade_9am_max hillnoon_min mid  ==> SEVEN',
#  'elevation_ultra aspect_medium Hillshade_9hillshade_9am_max mid  ==> SEVEN',
#  'elevation_high slope_high low  ==> FIVE',
#  'aspect_high Hillshade_9hillshade_9am_max hillnoon_min low  ==> FOUR',
#  'slope_high bullwark_a Hillshade_9hillshade_9am_min  ==> SIX',
#  'elevation_ultra aspect_high low  ==> SEVEN',
#  'elevation_ultra hillnoon_min  ==> SEVEN',
#  'elevation_ultra slope_medium hillnoon_min mid  ==> SEVEN',
#  'slope_high bullwark_a Hillshade_9hillshade_9am_min hillnoon_min  ==> SIX',
#  'elevation_ultra slope_high  ==> SEVEN',
#  'slope_high bullwark_a Hillshade_9hillshade_9am_min low  ==> SIX',
#  'elevation_ultra aspect_medium mid  ==> SEVEN',
#  'elevation_low Hillshade_9hillshade_9am_min hillnoon_max low  ==> FOUR',
#  '']

# %%
# now dividing the processed rules into X=>Y
processed_rule[0].partition('==>')

x=[]
y=[]
c=0
for string in processed_rule:
  x.append(string.partition('==>')[0].strip())
  y.append(string.partition('==>')[2].strip())
  # print(c)
  c=c+1

# %%
# reading the test file and preprocess it
test_data
file=open(test_data)
test_file=file.read()


df_test=pd.read_csv(test_data)
df_test2 = pd.read_csv(test_data)
del df_test['id']
del df_test['Horizontal_Distance_To_Hydrology']
del df_test['Vertical_Distance_To_Hydrology']


df_test


# x[0],y[0]  they represents the first rule

# dataframe is prepared
# now we will take a rule and match it against the test-case provided

#  'Elevation=elevation_ultra Hillshade_noon=hillnoon_min',

r_no=1
list_label_ans=[]
for row in df_test.itertuples(index=True):
  # storing the elements of the row in a set
  # print(r_no)
  r_no+=1
  row_set=set()
  row_set.add(getattr(row, "Elevation"))
  row_set.add(getattr(row, "Aspect"))
  row_set.add(getattr(row, "Slope"))
  row_set.add(getattr(row, "Wilderness"))
  row_set.add(getattr(row, "Soil_Type"))
  row_set.add(getattr(row, "Hillshade_9am"))
  row_set.add(getattr(row, "Hillshade_noon"))
  row_set.add(getattr(row, "Horizontal_Distance_To_Fire_Points"))


  # print(row_set)

  max_count=-1
  temp_solution=""

  for i in range(len(x)):
    rule=x[i].split(' ')
    if  len(rule)<3:
      continue
    count=0  
    flag=True
    for elem in rule:
      if(elem not in row_set):
        flag=False
        break
      else:
        count+=1
      
    if flag==True:
      if(count>max_count):
        max_count=count
        temp_solution=y[i] 
        break

  # print(temp_solution)
  if(temp_solution==""):
    list_label_ans.append('ONE')
  else:
    list_label_ans.append(temp_solution)


    # print(temp_solution+" "+str(max_count))
  

df_test['Label']=list_label_ans



# keeping track of rule that is matching the most of the times
df_test.Label.unique()
# row_set
df_test[1:50]
# Out:
#            Elevation         Aspect  ... Horizontal_Distance_To_Fire_Points  Label
# 1   elevation_medium  aspect_medium  ...                                low    ONE
# 2   elevation_medium    aspect_high  ...                                low  THREE
# 3   elevation_medium     aspect_low  ...                                low    SIX
# 4   elevation_medium    aspect_high  ...                                low  THREE
# 5   elevation_medium    aspect_high  ...                                low  THREE
# 6   elevation_medium    aspect_high  ...                                low  THREE
# 7   elevation_medium  aspect_medium  ...                                mid    ONE
# 8   elevation_medium  aspect_medium  ...                                low    SIX
# 9   elevation_medium    aspect_high  ...                                low  THREE
# 10  elevation_medium  aspect_medium  ...                                low    ONE
# 11  elevation_medium    aspect_high  ...                                low  THREE
# 12  elevation_medium    aspect_high  ...                                low  THREE
# 13  elevation_medium    aspect_high  ...                                low  THREE
# 14  elevation_medium  aspect_medium  ...                                low    ONE
# 15  elevation_medium  aspect_medium  ...                                low    ONE
# 16  elevation_medium  aspect_medium  ...                                low    SIX
# 17  elevation_medium  aspect_medium  ...                                low    SIX
# 18  elevation_medium    aspect_high  ...                                low    SIX
# 19  elevation_medium     aspect_low  ...                                low    SIX
# 20  elevation_medium    aspect_high  ...                                low    SIX
# 21  elevation_medium    aspect_high  ...                                low  THREE
# 22  elevation_medium    aspect_high  ...                                low  THREE
# 23  elevation_medium  aspect_medium  ...                                low    ONE
# 24  elevation_medium  aspect_medium  ...                                low    SIX
# 25  elevation_medium    aspect_high  ...                                low    SIX
# 26  elevation_medium     aspect_low  ...                                low    SIX
# 27  elevation_medium    aspect_high  ...                                mid  THREE
# 28  elevation_medium    aspect_high  ...                                mid    ONE
# 29  elevation_medium    aspect_high  ...                                low  THREE
# 30  elevation_medium    aspect_high  ...                                low  THREE
# 31  elevation_medium   aspect_ultra  ...                                low    SIX
# 32  elevation_medium     aspect_low  ...                                low    SIX
# 33  elevation_medium    aspect_high  ...                                low  THREE
# 34  elevation_medium    aspect_high  ...                                mid  THREE
# 35     elevation_low  aspect_medium  ...                                low   FOUR
# 36  elevation_medium  aspect_medium  ...                                low    ONE
# 37  elevation_medium     aspect_low  ...                                low    SIX
# 38  elevation_medium  aspect_medium  ...                                low    SIX
# 39  elevation_medium  aspect_medium  ...                                low    SIX
# 40  elevation_medium     aspect_low  ...                                low    ONE
# 41  elevation_medium    aspect_high  ...                                mid  THREE
# 42  elevation_medium  aspect_medium  ...                                low    ONE
# 43  elevation_medium  aspect_medium  ...                                low    ONE
# 44  elevation_medium     aspect_low  ...                                low    SIX
# 45  elevation_medium   aspect_ultra  ...                                low  THREE
# 46  elevation_medium     aspect_low  ...                                low  THREE
# 47  elevation_medium     aspect_low  ...                                low    ONE
# 48  elevation_medium     aspect_low  ...                                low    ONE
# 49  elevation_medium  aspect_medium  ...                                low    ONE
#
# [49 rows x 9 columns]

# %%
c = 0
for w in df_test['Label']:
  if (w == "ZERO"):
    df_test['Label'][c] = 0
    c = c+1
  elif w == "ONE":
    df_test['Label'][c] = 1
    c = c+1
  elif w == "TWO":
    df_test['Label'][c] = 2
    c = c+1
  elif w == "THREE":
    df_test['Label'][c] = 3
    c = c+1
  elif w == "FOUR":
    df_test['Label'][c] = 4
    c = c+1
  elif w == "FIVE":
    df_test['Label'][c] = 5
    c = c+1
  elif w == "SIX":
    df_test['Label'][c] = 6
    c = c+1
  else:
    df_test['Label'][c] = 7
    c = c+1
df_test[200:250]
# Out:
#             Elevation         Aspect  ... Horizontal_Distance_To_Fire_Points Label
# 200  elevation_medium    aspect_high  ...                                mid     3
# 201  elevation_medium    aspect_high  ...                                mid     1
# 202  elevation_medium    aspect_high  ...                                low     6
# 203  elevation_medium    aspect_high  ...                                low     3
# 204  elevation_medium    aspect_high  ...                                mid     3
# 205  elevation_medium    aspect_high  ...                                mid     1
# 206  elevation_medium    aspect_high  ...                                mid     1
# 207  elevation_medium    aspect_high  ...                                mid     1
# 208  elevation_medium     aspect_low  ...                                low     6
# 209  elevation_medium    aspect_high  ...                                low     3
# 210  elevation_medium    aspect_high  ...                                mid     3
# 211  elevation_medium    aspect_high  ...                                mid     3
# 212  elevation_medium     aspect_low  ...                                low     6
# 213  elevation_medium   aspect_ultra  ...                                mid     1
# 214  elevation_medium    aspect_high  ...                                mid     1
# 215  elevation_medium     aspect_low  ...                                low     6
# 216  elevation_medium    aspect_high  ...                                mid     3
# 217  elevation_medium    aspect_high  ...                                mid     1
# 218  elevation_medium     aspect_low  ...                                low     6
# 219  elevation_medium     aspect_low  ...                                low     6
# 220  elevation_medium    aspect_high  ...                                low     1
# 221  elevation_medium    aspect_high  ...                                low     3
# 222  elevation_medium    aspect_high  ...                                mid     3
# 223  elevation_medium    aspect_high  ...                                mid     3
# 224  elevation_medium   aspect_ultra  ...                                low     6
# 225  elevation_medium     aspect_low  ...                                low     6
# 226  elevation_medium    aspect_high  ...                                low     6
# 227  elevation_medium     aspect_low  ...                                low     6
# 228  elevation_medium    aspect_high  ...                                mid     3
# 229  elevation_medium    aspect_high  ...                                mid     3
# 230  elevation_medium     aspect_low  ...                                low     1
# 231  elevation_medium     aspect_low  ...                                low     6
# 232  elevation_medium     aspect_low  ...                                low     1
# 233  elevation_medium     aspect_low  ...                                low     6
# 234  elevation_medium     aspect_low  ...                                low     1
# 235  elevation_medium     aspect_low  ...                                low     1
# 236  elevation_medium     aspect_low  ...                                low     6
# 237  elevation_medium     aspect_low  ...                                mid     6
# 238  elevation_medium    aspect_high  ...                                mid     3
# 239  elevation_medium  aspect_medium  ...                                low     1
# 240  elevation_medium     aspect_low  ...                                low     6
# 241  elevation_medium    aspect_high  ...                                mid     1
# 242  elevation_medium     aspect_low  ...                                low     1
# 243  elevation_medium     aspect_low  ...                                low     6
# 244  elevation_medium     aspect_low  ...                                low     1
# 245  elevation_medium     aspect_low  ...                                mid     6
# 246  elevation_medium     aspect_low  ...                                mid     6
# 247  elevation_medium     aspect_low  ...                                mid     6
# 248  elevation_medium   aspect_ultra  ...                                low     6
# 249  elevation_medium     aspect_low  ...                                low     1
#
# [50 rows x 9 columns]

# %%
lst1 = []
lst2 = []
fin = pd.DataFrame()
for w in df_test2['id']:
  lst1.append(w)
for w in df_test['Label']:
  lst2.append(w)
fin['id'] = lst1
fin['label'] = lst2
fin.to_csv("drive/My Drive/dmg_assignment3/try_check.csv",index=False)
